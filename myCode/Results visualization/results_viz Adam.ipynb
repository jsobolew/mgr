# %%
from visualization import Visualization

# %%
project = 'rehersal ResNet CIFAR10 Task IL Adam'


viz = Visualization(project=project)
viz.plot_everything()
# Out:
# Error in run: 0 Error: "['acc_task_1', 'acc_task_2', 'acc_task_3', 'acc_task_4'] not in index"
# Exception with ids: Int64Index([0], dtype='int64'), exception: no numeric data to plot
# Error in run: 1 Error: "['acc_task_1', 'acc_task_2', 'acc_task_3', 'acc_task_4'] not in index"
# Error in run: 2 Error: "['acc_task_1', 'acc_task_2', 'acc_task_3', 'acc_task_4'] not in index"
# Error in run: 3 Error: "['acc_task_1', 'acc_task_2', 'acc_task_3', 'acc_task_4'] not in index"
# Error in run: 4 Error: "['acc_task_1', 'acc_task_2', 'acc_task_3', 'acc_task_4'] not in index"
# Error in run: 5 Error: "['acc_task_1', 'acc_task_2', 'acc_task_3', 'acc_task_4'] not in index"
# Exception with ids: Int64Index([1, 2, 3, 4, 5], dtype='int64'), exception: no numeric data to plot
# Error in run: 16 Error: "['acc_task_1', 'acc_task_2', 'acc_task_3', 'acc_task_4'] not in index"
# Exception with ids: Int64Index([16], dtype='int64'), exception: no numeric data to plot
