# %%
import wandb
import pandas as pd
import numpy as np
import json
import pickle

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # TODO
# delete all runs where there is [any_number, 0] in classes_list

# %%
api = wandb.Api()
projects=api.projects(entity='qba')
for p in projects:
    print(p.name)
# Out:
# rehersal VGG CIFAR10 Task IL
# rehersal Alexnet MNIST Task IL CL
# rehersal SmallNett MNIST Task IL
# rehersal ResNet18 CIFAR100 Task IL
# rehersal Alexnet MNIST Task IL Adam
# rehersal ResNet CIFAR10 Task IL Adam
# rehersal Alexnet CIFAR100 Task IL
# rehersalAlexnetMNISTTaskILtr-tsplitv2
# rehersalResNetCIFAR10TaskIL
# rehersal Alexnet MNIST Class IL
# rehersal ResNet CIFAR10 Task IL
# rehersal Alexnet MNIST Task IL tr-t split v2
# rehersal Alexnet MNIST Task IL tr-t split
# rehersal Alexnet MNIST Task IL 2
# rehersal Alexnet MNIST Task IL
# no rehersal Alexnet MNIST Task IL
# no rehersal small net MNIST Class IL
# no rehersal small net MNIST Task IL
# rehersal small net MNIST Task IL
# rehersal small net MNIST
# many-seeds
# lightning-hydra-template
# pretraining and mnist

# %%
project = 'rehersal ResNet CIFAR10 Task IL'
runs = api.runs(f"qba/{project}")

# %%
runs_list = []
for run in runs:
    runs_list.append(run.config)
df = pd.DataFrame(runs_list).astype(str)

# %%
df
# Out:
#     loss    setup epochs  dataset                          project optimizer  \
# 0     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 1     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 2     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 3     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 4     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 5     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 6     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 7     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 8     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 9     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 10    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 11    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 12    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 13    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 14    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 15    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 16    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 17    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 18    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 19    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 20    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 21    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 22    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 23    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 24    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 25    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 26    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 27    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 28    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 29    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 30    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 31    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 32    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 33    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 34    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 35    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 36    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 37    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 38    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 39    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 40    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 41    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 42    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 43    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 44    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 45    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 46    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 47    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 48    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 49    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 50    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 51    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 52    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 53    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 54    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 55    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 56    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 57    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 58    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 59    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 60    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 61    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 62    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 63    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 64    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 65    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 66    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 67    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 68    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 69    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 70    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 71    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 72    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 73    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 74    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 75    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 76    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 77    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 78    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 79    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 80    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 81    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 82    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 83    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 84    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 85    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 86    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 87    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 88    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 89    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 90    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 91    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 92    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 93    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 94    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 95    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 96    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 97    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 98    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 99    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 100   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 101   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 102   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 103   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 104   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 105   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 106   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 107   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 108   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 109   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 110   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 111   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 112   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 113   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 114   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 115   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 116   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 117   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 118   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 119   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 120   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 121   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 122   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 123   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 124   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 125   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 126   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 127   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 128   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 129   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 130   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 131   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 132   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 133   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 134   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 135   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 136   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 137   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 138   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 139   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 140   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 141   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 142  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 143  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 144  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 145  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 146  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 147  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 148  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 149  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 150  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 151  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 152  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 153  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 154  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 155  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 156  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 157  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 158  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 159  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 160  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 161  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 162  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 163  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 164  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 165  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 166  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 167  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 168  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 169  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 170  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 171  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 172  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 173  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 174  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 175  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 176  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 177  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 178  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 179  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 180  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 181  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 182  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 183  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 184  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 185  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 186  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 187  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 188  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 189  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 190  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 191  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 192  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 193  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 194  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 195  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 196  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 197  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 198  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 199  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 200  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 201  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 202  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 203  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 204  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 205  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 206  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 207  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 208  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 209  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 210  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 211  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 212  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 213  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 214  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 215  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 216  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 217  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 218  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 219  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 220  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 221  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 222  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 223  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 224  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 225  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 226  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 227  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 228  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 229  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 230  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 231  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 232  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 233  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 234  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 235  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 236  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 237  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 238  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 239  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 240  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 241  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 242  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 243  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 244  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 245  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 246  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 247  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 248  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 249  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
#
#     batch_size num_classes pretraining architecture  \
# 0        128.0        10.0       False     ResNet18
# 1        128.0        10.0       False     ResNet18
# 2        128.0        10.0       False     ResNet18
# 3        128.0        10.0       False     ResNet18
# 4        128.0        10.0       False     ResNet18
# 5        128.0        10.0       False     ResNet18
# 6        128.0        10.0       False     ResNet18
# 7        128.0        10.0       False     ResNet18
# 8        128.0        10.0       False     ResNet18
# 9        128.0        10.0       False     ResNet18
# 10       128.0        10.0       False     ResNet18
# 11       128.0        10.0       False     ResNet18
# 12       128.0        10.0       False     ResNet18
# 13       128.0        10.0       False     ResNet18
# 14       128.0        10.0        True     ResNet18
# 15       128.0        10.0       False     ResNet18
# 16       128.0        10.0        True     ResNet18
# 17       128.0        10.0        True     ResNet18
# 18       128.0        10.0       False     ResNet18
# 19       128.0        10.0       False     ResNet18
# 20       128.0        10.0       False     ResNet18
# 21       128.0        10.0        True     ResNet18
# 22       128.0        10.0       False     ResNet18
# 23       128.0        10.0       False     ResNet18
# 24       128.0        10.0        True     ResNet18
# 25       128.0        10.0        True     ResNet18
# 26       128.0        10.0        True     ResNet18
# 27       128.0        10.0        True     ResNet18
# 28       128.0        10.0        True     ResNet18
# 29       128.0        10.0       False     ResNet18
# 30       128.0        10.0       False     ResNet18
# 31       128.0        10.0       False     ResNet18
# 32       128.0        10.0        True     ResNet18
# 33       128.0        10.0       False     ResNet18
# 34       128.0        10.0       False     ResNet18
# 35       128.0        10.0        True     ResNet18
# 36       128.0        10.0        True     ResNet18
# 37       128.0        10.0        True     ResNet18
# 38       128.0        10.0       False     ResNet18
# 39       128.0        10.0       False     ResNet18
# 40       128.0        10.0        True     ResNet18
# 41       128.0        10.0       False     ResNet18
# 42       128.0        10.0        True     ResNet18
# 43       128.0        10.0       False     ResNet18
# 44       128.0        10.0        True     ResNet18
# 45       128.0        10.0        True     ResNet18
# 46       128.0        10.0        True     ResNet18
# 47       128.0        10.0       False     ResNet18
# 48       128.0        10.0        True     ResNet18
# 49       128.0        10.0        True     ResNet18
# 50       128.0        10.0        True     ResNet18
# 51       128.0        10.0       False     ResNet18
# 52       128.0        10.0        True     ResNet18
# 53       128.0        10.0        True     ResNet18
# 54       128.0        10.0       False     ResNet18
# 55       128.0        10.0       False     ResNet18
# 56       128.0        10.0       False     ResNet18
# 57       128.0        10.0       False     ResNet18
# 58       128.0        10.0       False     ResNet18
# 59       128.0        10.0        True     ResNet18
# 60       128.0        10.0        True     ResNet18
# 61       128.0        10.0        True     ResNet18
# 62       128.0        10.0        True     ResNet18
# 63       128.0        10.0        True     ResNet18
# 64       128.0        10.0       False     ResNet18
# 65       128.0        10.0       False     ResNet18
# 66       128.0        10.0       False     ResNet18
# 67       128.0        10.0        True     ResNet18
# 68       128.0        10.0        True     ResNet18
# 69       128.0        10.0        True     ResNet18
# 70       128.0        10.0        True     ResNet18
# 71       128.0        10.0        True     ResNet18
# 72       128.0        10.0        True     ResNet18
# 73       128.0        10.0        True     ResNet18
# 74       128.0        10.0       False     ResNet18
# 75       128.0        10.0       False     ResNet18
# 76       128.0        10.0       False     ResNet18
# 77       128.0        10.0       False     ResNet18
# 78       128.0        10.0       False     ResNet18
# 79       128.0        10.0       False     ResNet18
# 80       128.0        10.0       False     ResNet18
# 81       128.0        10.0       False     ResNet18
# 82       128.0        10.0        True     ResNet18
# 83       128.0        10.0        True     ResNet18
# 84       128.0        10.0        True     ResNet18
# 85       128.0        10.0        True     ResNet18
# 86       128.0        10.0        True     ResNet18
# 87       128.0        10.0        True     ResNet18
# 88       128.0        10.0        True     ResNet18
# 89       128.0        10.0        True     ResNet18
# 90       128.0        10.0        True     ResNet18
# 91       128.0        10.0        True     ResNet18
# 92       128.0        10.0       False     ResNet18
# 93       128.0        10.0       False     ResNet18
# 94       128.0        10.0       False     ResNet18
# 95       128.0        10.0       False     ResNet18
# 96       128.0        10.0       False     ResNet18
# 97       128.0        10.0       False     ResNet18
# 98       128.0        10.0       False     ResNet18
# 99       128.0        10.0       False     ResNet18
# 100      128.0        10.0        True     ResNet18
# 101      128.0        10.0        True     ResNet18
# 102      128.0        10.0        True     ResNet18
# 103      128.0        10.0        True     ResNet18
# 104      128.0        10.0        True     ResNet18
# 105      128.0        10.0        True     ResNet18
# 106      128.0        10.0        True     ResNet18
# 107      128.0        10.0        True     ResNet18
# 108      128.0        10.0        True     ResNet18
# 109      128.0        10.0        True     ResNet18
# 110      128.0        10.0       False     ResNet18
# 111      128.0        10.0       False     ResNet18
# 112      128.0        10.0       False     ResNet18
# 113      128.0        10.0       False     ResNet18
# 114      128.0        10.0       False     ResNet18
# 115      128.0        10.0       False     ResNet18
# 116      128.0        10.0       False     ResNet18
# 117      128.0        10.0       False     ResNet18
# 118      128.0        10.0        True     ResNet18
# 119      128.0        10.0        True     ResNet18
# 120      128.0        10.0        True     ResNet18
# 121      128.0        10.0        True     ResNet18
# 122      128.0        10.0        True     ResNet18
# 123      128.0        10.0        True     ResNet18
# 124      128.0        10.0        True     ResNet18
# 125      128.0        10.0        True     ResNet18
# 126      128.0        10.0        True     ResNet18
# 127      128.0        10.0        True     ResNet18
# 128      128.0        10.0        True     ResNet18
# 129      128.0        10.0       False     ResNet18
# 130      128.0        10.0       False     ResNet18
# 131      128.0        10.0       False     ResNet18
# 132      128.0        10.0       False     ResNet18
# 133      128.0        10.0       False     ResNet18
# 134      128.0        10.0       False     ResNet18
# 135      128.0        10.0       False     ResNet18
# 136      128.0        10.0       False     ResNet18
# 137      128.0        10.0        True     ResNet18
# 138      128.0        10.0        True     ResNet18
# 139      128.0        10.0        True     ResNet18
# 140      128.0        10.0        True     ResNet18
# 141      128.0        10.0        True     ResNet18
# 142      128.0        10.0       False     ResNet18
# 143      128.0        10.0       False     ResNet18
# 144      128.0        10.0       False     ResNet18
# 145      128.0        10.0       False     ResNet18
# 146      128.0        10.0       False     ResNet18
# 147      128.0        10.0       False     ResNet18
# 148      128.0        10.0       False     ResNet18
# 149      128.0        10.0       False     ResNet18
# 150      128.0        10.0       False     ResNet18
# 151      128.0        10.0       False     ResNet18
# 152      128.0        10.0       False     ResNet18
# 153      128.0        10.0       False     ResNet18
# 154      128.0        10.0       False     ResNet18
# 155      128.0        10.0        True     ResNet18
# 156      128.0        10.0        True     ResNet18
# 157      128.0        10.0        True     ResNet18
# 158      128.0        10.0        True     ResNet18
# 159      128.0        10.0        True     ResNet18
# 160      128.0        10.0        True     ResNet18
# 161      128.0        10.0        True     ResNet18
# 162      128.0        10.0        True     ResNet18
# 163      128.0        10.0        True     ResNet18
# 164      128.0        10.0        True     ResNet18
# 165      128.0        10.0       False     ResNet18
# 166      128.0        10.0       False     ResNet18
# 167      128.0        10.0       False     ResNet18
# 168      128.0        10.0       False     ResNet18
# 169      128.0        10.0       False     ResNet18
# 170      128.0        10.0       False     ResNet18
# 171      128.0        10.0       False     ResNet18
# 172      128.0        10.0       False     ResNet18
# 173      128.0        10.0       False     ResNet18
# 174      128.0        10.0       False     ResNet18
# 175      128.0        10.0       False     ResNet18
# 176      128.0        10.0       False     ResNet18
# 177      128.0        10.0       False     ResNet18
# 178      128.0        10.0       False     ResNet18
# 179      128.0        10.0       False     ResNet18
# 180      128.0        10.0        True     ResNet18
# 181      128.0        10.0        True     ResNet18
# 182      128.0        10.0        True     ResNet18
# 183      128.0        10.0        True     ResNet18
# 184      128.0        10.0        True     ResNet18
# 185      128.0        10.0        True     ResNet18
# 186      128.0        10.0        True     ResNet18
# 187      128.0        10.0        True     ResNet18
# 188      128.0        10.0        True     ResNet18
# 189      128.0        10.0        True     ResNet18
# 190      128.0        10.0       False     ResNet18
# 191      128.0        10.0       False     ResNet18
# 192      128.0        10.0       False     ResNet18
# 193      128.0        10.0       False     ResNet18
# 194      128.0        10.0       False     ResNet18
# 195        nan         nan       False     ResNet18
# 196        nan         nan       False     ResNet18
# 197        nan         nan       False     ResNet18
# 198        nan         nan       False     ResNet18
# 199        nan         nan       False     ResNet18
# 200        nan         nan       False     ResNet18
# 201        nan         nan       False     ResNet18
# 202        nan         nan       False     ResNet18
# 203        nan         nan       False     ResNet18
# 204        nan         nan       False     ResNet18
# 205        nan         nan        True     ResNet18
# 206        nan         nan        True     ResNet18
# 207        nan         nan        True     ResNet18
# 208        nan         nan        True     ResNet18
# 209        nan         nan        True     ResNet18
# 210        nan         nan        True     ResNet18
# 211        nan         nan        True     ResNet18
# 212        nan         nan        True     ResNet18
# 213        nan         nan        True     ResNet18
# 214        nan         nan        True     ResNet18
# 215        nan         nan        True     ResNet18
# 216        nan         nan        True     ResNet18
# 217        nan         nan        True     ResNet18
# 218        nan         nan        True     ResNet18
# 219        nan         nan        True     ResNet18
# 220        nan         nan        True     ResNet18
# 221        nan         nan        True     ResNet18
# 222        nan         nan        True     ResNet18
# 223        nan         nan        True     ResNet18
# 224        nan         nan        True     ResNet18
# 225        nan         nan       False     ResNet18
# 226        nan         nan       False     ResNet18
# 227        nan         nan       False     ResNet18
# 228        nan         nan       False     ResNet18
# 229        nan         nan       False     ResNet18
# 230        nan         nan       False     ResNet18
# 231        nan         nan       False     ResNet18
# 232        nan         nan       False     ResNet18
# 233        nan         nan       False     ResNet18
# 234        nan         nan       False     ResNet18
# 235        nan         nan       False     ResNet18
# 236        nan         nan       False     ResNet18
# 237        nan         nan       False     ResNet18
# 238        nan         nan        True     ResNet18
# 239        nan         nan        True     ResNet18
# 240        nan         nan        True     ResNet18
# 241        nan         nan        True     ResNet18
# 242        nan         nan        True     ResNet18
# 243        nan         nan        True     ResNet18
# 244        nan         nan        True     ResNet18
# 245        nan         nan        True     ResNet18
# 246        nan         nan        True     ResNet18
# 247        nan         nan        True     ResNet18
# 248        nan         nan        True     ResNet18
# 249        nan         nan        True     ResNet18
#
#                                  classes_list learning_rate classes_per_task  \
# 0    [[4, 9], [5, 6], [2, 7], [3, 8], [0, 1]]         0.003              2.0
# 1    [[1, 3], [0, 8], [6, 7], [4, 9], [2, 5]]         0.003              2.0
# 2    [[2, 3], [1, 8], [4, 9], [5, 7], [0, 6]]         0.003              2.0
# 3    [[1, 2], [3, 6], [7, 8], [0, 9], [4, 5]]         0.003              2.0
# 4    [[0, 7], [4, 5], [8, 9], [2, 6], [1, 3]]         0.003              2.0
# 5    [[3, 7], [0, 9], [1, 8], [2, 4], [5, 6]]         0.003              2.0
# 6    [[6, 7], [2, 9], [5, 8], [3, 4], [0, 1]]         0.003              2.0
# 7    [[3, 7], [0, 4], [6, 9], [1, 5], [2, 8]]         0.003              2.0
# 8    [[6, 7], [2, 5], [4, 9], [3, 8], [0, 1]]         0.003              2.0
# 9    [[3, 9], [1, 2], [0, 7], [5, 8], [4, 6]]         0.003              2.0
# 10   [[0, 2], [6, 9], [5, 7], [3, 8], [1, 4]]         0.003              2.0
# 11   [[5, 7], [2, 9], [3, 4], [6, 8], [0, 1]]         0.003              2.0
# 12   [[3, 5], [2, 8], [7, 9], [0, 6], [1, 4]]         0.003              2.0
# 13   [[4, 8], [5, 6], [7, 9], [0, 1], [2, 3]]         0.003              2.0
# 14   [[4, 5], [2, 9], [6, 7], [1, 3], [0, 8]]         0.003              2.0
# 15   [[0, 5], [1, 3], [8, 9], [2, 7], [4, 6]]         0.003              2.0
# 16   [[1, 7], [0, 2], [5, 6], [3, 8], [4, 9]]         0.003              2.0
# 17   [[1, 4], [3, 9], [6, 8], [5, 7], [0, 2]]         0.003              2.0
# 18   [[0, 6], [1, 5], [4, 9], [3, 7], [2, 8]]         0.003              2.0
# 19   [[1, 6], [7, 9], [5, 8], [3, 4], [0, 2]]         0.003              2.0
# 20   [[5, 7], [4, 8], [0, 9], [1, 3], [2, 6]]         0.003              2.0
# 21   [[0, 5], [4, 8], [3, 7], [1, 2], [6, 9]]         0.003              2.0
# 22   [[1, 2], [7, 8], [5, 6], [0, 9], [3, 4]]         0.003              2.0
# 23   [[0, 5], [3, 7], [1, 9], [2, 6], [4, 8]]         0.003              2.0
# 24   [[1, 5], [6, 7], [0, 2], [3, 8], [4, 9]]         0.003              2.0
# 25   [[3, 4], [0, 8], [5, 7], [2, 6], [1, 9]]         0.003              2.0
# 26   [[1, 3], [4, 9], [2, 6], [5, 8], [0, 7]]         0.003              2.0
# 27   [[0, 6], [1, 4], [3, 5], [2, 7], [8, 9]]         0.003              2.0
# 28   [[1, 5], [3, 8], [0, 4], [2, 7], [6, 9]]         0.003              2.0
# 29   [[1, 5], [0, 9], [2, 8], [6, 7], [3, 4]]         0.003              2.0
# 30   [[1, 3], [8, 9], [2, 5], [4, 6], [0, 7]]         0.003              2.0
# 31   [[5, 6], [3, 9], [0, 7], [1, 8], [2, 4]]         0.003              2.0
# 32   [[1, 5], [3, 7], [4, 9], [0, 8], [2, 6]]         0.003              2.0
# 33   [[5, 6], [4, 8], [7, 9], [0, 3], [1, 2]]         0.003              2.0
# 34   [[3, 6], [2, 7], [0, 5], [1, 8], [4, 9]]         0.003              2.0
# 35   [[2, 7], [0, 9], [1, 5], [6, 8], [3, 4]]         0.003              2.0
# 36   [[0, 5], [7, 9], [4, 8], [1, 3], [2, 6]]         0.003              2.0
# 37   [[3, 5], [8, 9], [2, 6], [1, 4], [0, 7]]         0.003              2.0
# 38   [[2, 8], [0, 9], [4, 5], [3, 7], [1, 6]]         0.003              2.0
# 39   [[2, 9], [3, 4], [0, 8], [5, 6], [1, 7]]         0.003              2.0
# 40   [[1, 9], [2, 3], [6, 7], [4, 8], [0, 5]]         0.003              2.0
# 41   [[6, 8], [2, 5], [0, 4], [3, 9], [1, 7]]         0.003              2.0
# 42   [[5, 8], [0, 7], [2, 4], [3, 9], [1, 6]]         0.003              2.0
# 43   [[3, 6], [1, 7], [4, 5], [0, 9], [2, 8]]         0.003              2.0
# 44   [[5, 7], [3, 6], [4, 8], [0, 1], [2, 9]]         0.003              2.0
# 45   [[6, 9], [4, 8], [0, 3], [1, 2], [5, 7]]         0.003              2.0
# 46   [[1, 2], [8, 9], [3, 4], [0, 6], [5, 7]]         0.003              2.0
# 47   [[4, 6], [0, 9], [1, 3], [2, 7], [5, 8]]         0.003              2.0
# 48   [[3, 6], [2, 7], [1, 9], [0, 8], [4, 5]]         0.003              2.0
# 49   [[1, 7], [0, 4], [2, 5], [3, 9], [6, 8]]         0.003              2.0
# 50   [[2, 5], [0, 7], [1, 6], [8, 9], [3, 4]]         0.003              2.0
# 51   [[1, 6], [0, 8], [7, 9], [2, 5], [3, 4]]         0.003              2.0
# 52   [[0, 9], [2, 6], [3, 5], [4, 7], [1, 8]]         0.003              2.0
# 53   [[3, 7], [4, 5], [0, 6], [8, 9], [1, 2]]         0.003              2.0
# 54   [[6, 8], [3, 9], [2, 4], [0, 5], [1, 7]]         0.003              2.0
# 55   [[1, 8], [4, 9], [0, 3], [2, 5], [6, 7]]         0.003              2.0
# 56   [[2, 4], [1, 9], [0, 6], [7, 8], [3, 5]]         0.003              2.0
# 57   [[1, 6], [3, 4], [2, 5], [0, 7], [8, 9]]         0.003              2.0
# 58   [[1, 7], [0, 3], [2, 4], [8, 9], [5, 6]]         0.003              2.0
# 59   [[4, 6], [1, 5], [3, 7], [2, 8], [0, 9]]         0.003              2.0
# 60   [[1, 9], [2, 5], [0, 3], [4, 6], [7, 8]]         0.003              2.0
# 61   [[4, 5], [3, 8], [1, 6], [7, 9], [0, 2]]         0.003              2.0
# 62   [[2, 8], [6, 9], [4, 5], [1, 7], [0, 3]]         0.003              2.0
# 63   [[5, 9], [4, 7], [0, 1], [3, 8], [2, 6]]         0.003              2.0
# 64   [[2, 7], [6, 8], [1, 9], [0, 5], [3, 4]]         0.003              2.0
# 65   [[4, 6], [8, 9], [1, 5], [2, 7], [0, 3]]         0.003              2.0
# 66   [[0, 9], [6, 8], [1, 7], [3, 4], [2, 5]]         0.003              2.0
# 67   [[3, 5], [8, 9], [2, 6], [0, 1], [4, 7]]         0.003              2.0
# 68   [[5, 8], [7, 9], [2, 3], [0, 6], [1, 4]]         0.003              2.0
# 69   [[6, 4], [3, 1], [8, 5], [0, 9], [7, 2]]         0.003              2.0
# 70   [[8, 1], [7, 4], [3, 2], [9, 0], [6, 5]]         0.003              2.0
# 71   [[0, 3], [8, 2], [1, 5], [7, 4], [6, 9]]         0.003              2.0
# 72   [[1, 4], [8, 0], [9, 6], [7, 3], [5, 2]]         0.003              2.0
# 73   [[9, 6], [7, 1], [2, 8], [5, 4], [0, 3]]         0.003              2.0
# 74   [[5, 3], [6, 2], [1, 8], [0, 4], [9, 7]]         0.003              2.0
# 75   [[7, 6], [9, 1], [3, 4], [8, 5], [0, 2]]         0.003              2.0
# 76   [[8, 7], [3, 9], [0, 6], [2, 5], [1, 4]]         0.003              2.0
# 77   [[8, 7], [9, 4], [3, 1], [2, 0], [5, 6]]         0.003              2.0
# 78   [[1, 2], [0, 5], [7, 8], [4, 9], [3, 6]]         0.003              2.0
# 79   [[6, 1], [7, 9], [5, 4], [3, 2], [8, 0]]         0.003              2.0
# 80   [[5, 2], [1, 3], [7, 4], [8, 9], [6, 0]]         0.003              2.0
# 81   [[2, 1], [7, 9], [4, 8], [0, 6], [3, 5]]         0.003              2.0
# 82   [[2, 6], [4, 8], [0, 5], [7, 9], [1, 3]]         0.003              2.0
# 83   [[6, 2], [9, 7], [8, 3], [5, 4], [0, 1]]         0.003              2.0
# 84   [[2, 0], [6, 8], [4, 5], [1, 3], [9, 7]]         0.003              2.0
# 85   [[7, 0], [3, 4], [8, 6], [9, 2], [5, 1]]         0.003              2.0
# 86   [[8, 1], [3, 7], [2, 6], [0, 5], [9, 4]]         0.003              2.0
# 87   [[2, 4], [3, 0], [1, 5], [7, 6], [9, 8]]         0.003              2.0
# 88   [[6, 1], [7, 3], [8, 5], [2, 4], [0, 9]]         0.003              2.0
# 89   [[0, 1], [8, 4], [7, 3], [5, 2], [9, 6]]         0.003              2.0
# 90   [[2, 5], [8, 1], [6, 0], [3, 9], [4, 7]]         0.003              2.0
# 91   [[3, 8], [6, 0], [7, 9], [4, 5], [1, 2]]         0.003              2.0
# 92   [[6, 8], [5, 4], [0, 3], [1, 2], [9, 7]]         0.003              2.0
# 93   [[4, 0], [3, 6], [5, 8], [9, 2], [1, 7]]         0.003              2.0
# 94   [[6, 0], [3, 7], [5, 1], [8, 2], [4, 9]]         0.003              2.0
# 95   [[8, 0], [9, 7], [3, 1], [2, 6], [4, 5]]         0.003              2.0
# 96   [[3, 1], [6, 0], [9, 8], [5, 7], [2, 4]]         0.003              2.0
# 97   [[7, 4], [0, 6], [1, 2], [8, 3], [9, 5]]         0.003              2.0
# 98   [[4, 7], [6, 8], [2, 1], [5, 3], [9, 0]]         0.003              2.0
# 99   [[1, 4], [2, 0], [8, 5], [9, 7], [3, 6]]         0.003              2.0
# 100  [[8, 3], [4, 5], [2, 7], [1, 6], [9, 0]]         0.003              2.0
# 101  [[1, 5], [9, 8], [7, 6], [4, 0], [2, 3]]         0.003              2.0
# 102  [[1, 9], [5, 2], [4, 6], [3, 8], [0, 7]]         0.003              2.0
# 103  [[5, 3], [6, 1], [0, 4], [2, 8], [7, 9]]         0.003              2.0
# 104  [[5, 0], [6, 4], [2, 9], [1, 3], [8, 7]]         0.003              2.0
# 105  [[2, 6], [1, 9], [4, 5], [7, 8], [0, 3]]         0.003              2.0
# 106  [[3, 5], [8, 1], [0, 7], [6, 9], [2, 4]]         0.003              2.0
# 107  [[7, 5], [3, 0], [1, 9], [6, 4], [8, 2]]         0.003              2.0
# 108  [[3, 7], [4, 8], [9, 2], [0, 5], [1, 6]]         0.003              2.0
# 109  [[2, 1], [7, 8], [0, 9], [3, 6], [5, 4]]         0.003              2.0
# 110  [[5, 6], [3, 2], [9, 7], [0, 4], [8, 1]]         0.003              2.0
# 111  [[9, 6], [7, 2], [4, 0], [1, 3], [8, 5]]         0.003              2.0
# 112  [[6, 9], [2, 8], [0, 1], [7, 3], [5, 4]]         0.003              2.0
# 113  [[3, 2], [7, 6], [8, 5], [0, 1], [4, 9]]         0.003              2.0
# 114  [[0, 1], [5, 4], [9, 2], [7, 6], [8, 3]]         0.003              2.0
# 115  [[5, 8], [1, 4], [9, 3], [2, 7], [0, 6]]         0.003              2.0
# 116  [[5, 2], [0, 1], [8, 7], [3, 9], [4, 6]]         0.003              2.0
# 117  [[2, 6], [0, 4], [1, 9], [7, 8], [3, 5]]         0.003              2.0
# 118  [[9, 8], [0, 1], [2, 3], [4, 7], [5, 6]]         0.003              2.0
# 119  [[6, 5], [9, 0], [4, 3], [7, 2], [8, 1]]         0.003              2.0
# 120  [[7, 9], [8, 1], [3, 0], [6, 2], [4, 5]]         0.003              2.0
# 121  [[4, 6], [3, 2], [1, 0], [7, 8], [5, 9]]         0.003              2.0
# 122  [[0, 5], [6, 3], [9, 8], [7, 4], [2, 1]]         0.003              2.0
# 123  [[2, 6], [8, 7], [0, 5], [1, 3], [9, 4]]         0.003              2.0
# 124  [[2, 9], [0, 8], [1, 5], [7, 3], [4, 6]]         0.003              2.0
# 125  [[5, 0], [1, 7], [8, 9], [6, 3], [4, 2]]         0.003              2.0
# 126  [[1, 3], [2, 9], [6, 4], [0, 7], [5, 8]]         0.003              2.0
# 127  [[1, 0], [3, 2], [4, 6], [7, 5], [8, 9]]         0.003              2.0
# 128  [[6, 0], [8, 9], [7, 5], [3, 2], [4, 1]]         0.003              2.0
# 129  [[2, 5], [0, 4], [8, 9], [3, 7], [6, 1]]         0.003              2.0
# 130  [[0, 7], [2, 1], [5, 8], [6, 3], [4, 9]]         0.003              2.0
# 131  [[1, 4], [2, 8], [9, 3], [0, 7], [5, 6]]         0.003              2.0
# 132  [[3, 7], [2, 8], [0, 6], [4, 5], [9, 1]]         0.003              2.0
# 133  [[3, 0], [8, 1], [6, 9], [5, 2], [7, 4]]         0.003              2.0
# 134  [[3, 4], [5, 1], [7, 0], [8, 9], [6, 2]]         0.003              2.0
# 135  [[2, 3], [5, 4], [1, 0], [7, 9], [8, 6]]         0.003              2.0
# 136  [[7, 0], [5, 4], [9, 2], [3, 6], [1, 8]]         0.003              2.0
# 137  [[1, 5], [8, 4], [6, 7], [3, 9], [2, 0]]         0.003              2.0
# 138  [[1, 8], [4, 2], [0, 5], [9, 6], [3, 7]]         0.003              2.0
# 139  [[6, 3], [2, 0], [9, 5], [4, 7], [8, 1]]         0.003              2.0
# 140  [[1, 7], [3, 0], [5, 2], [6, 4], [8, 9]]         0.003              2.0
# 141  [[9, 6], [7, 1], [0, 4], [8, 5], [2, 3]]         0.003              2.0
# 142  [[0, 7], [2, 4], [8, 3], [6, 9], [5, 1]]         0.003              2.0
# 143  [[5, 3], [6, 4], [0, 8], [7, 1], [9, 2]]         0.003              2.0
# 144  [[0, 1], [5, 6], [4, 8], [3, 7], [9, 2]]         0.003              2.0
# 145  [[1, 8], [9, 3], [4, 7], [0, 6], [5, 2]]         0.003              2.0
# 146  [[5, 3], [8, 4], [9, 6], [1, 7], [2, 0]]         0.003              2.0
# 147  [[4, 6], [7, 5], [2, 0], [1, 8], [3, 9]]         0.003              2.0
# 148  [[5, 2], [3, 9], [6, 8], [0, 1], [4, 7]]         0.003              2.0
# 149  [[8, 0], [5, 2], [6, 3], [7, 4], [9, 1]]         0.003              2.0
# 150  [[3, 7], [8, 2], [5, 9], [0, 6], [1, 4]]         0.003              2.0
# 151  [[2, 5], [7, 0], [6, 4], [3, 9], [8, 1]]         0.003              2.0
# 152  [[0, 9], [3, 5], [2, 1], [6, 7], [4, 8]]         0.003              2.0
# 153  [[2, 8], [9, 0], [3, 5], [6, 7], [4, 1]]         0.003              2.0
# 154  [[0, 6], [5, 1], [8, 7], [4, 2], [3, 9]]         0.003              2.0
# 155  [[5, 4], [1, 6], [3, 0], [8, 9], [2, 7]]         0.003              2.0
# 156  [[0, 8], [6, 3], [5, 1], [7, 9], [4, 2]]         0.003              2.0
# 157  [[8, 0], [3, 4], [9, 2], [6, 1], [5, 7]]         0.003              2.0
# 158  [[5, 6], [3, 8], [9, 0], [2, 4], [7, 1]]         0.003              2.0
# 159  [[1, 0], [6, 7], [3, 2], [9, 8], [5, 4]]         0.003              2.0
# 160  [[6, 0], [7, 8], [9, 2], [4, 1], [3, 5]]         0.003              2.0
# 161  [[0, 9], [1, 7], [3, 8], [5, 4], [2, 6]]         0.003              2.0
# 162  [[5, 4], [9, 0], [1, 8], [2, 7], [3, 6]]         0.003              2.0
# 163  [[8, 7], [0, 6], [3, 9], [1, 5], [2, 4]]         0.003              2.0
# 164  [[6, 4], [8, 5], [1, 2], [7, 0], [9, 3]]         0.003              2.0
# 165  [[0, 2], [8, 5], [4, 6], [1, 9], [3, 7]]         0.003              2.0
# 166  [[4, 6], [8, 2], [3, 9], [1, 5], [7, 0]]         0.003              2.0
# 167  [[6, 1], [0, 3], [7, 2], [8, 4], [5, 9]]         0.003              2.0
# 168  [[9, 3], [4, 7], [8, 0], [2, 1], [6, 5]]         0.003              2.0
# 169  [[4, 6], [0, 5], [7, 8], [2, 9], [3, 1]]         0.003              2.0
# 170  [[6, 8], [0, 5], [4, 7], [3, 9], [1, 2]]         0.003              2.0
# 171  [[1, 3], [4, 7], [5, 8], [6, 9], [2, 0]]         0.003              2.0
# 172  [[3, 0], [2, 5], [7, 6], [4, 1], [8, 9]]         0.003              2.0
# 173  [[4, 5], [8, 3], [9, 2], [7, 1], [6, 0]]         0.003              2.0
# 174  [[6, 9], [1, 2], [0, 8], [7, 3], [4, 5]]         0.003              2.0
# ...
# 126     dead_leaves-oriented                nan                  128
# 127     dead_leaves-oriented                nan                  128
# 128     dead_leaves-oriented                nan                  128
# 129     dead_leaves-oriented                nan                  128
# 130     dead_leaves-oriented                nan                  128
# 131     dead_leaves-oriented                nan                  128
# 132     dead_leaves-oriented                nan                  128
# 133        dead_leaves-mixed                nan                  128
# 134        dead_leaves-mixed                nan                  128
# 135        dead_leaves-mixed                nan                  128
# 136        dead_leaves-mixed                nan                  128
# 137        dead_leaves-mixed                nan                  128
# 138        dead_leaves-mixed                nan                  128
# 139        dead_leaves-mixed                nan                  128
# 140        dead_leaves-mixed                nan                  128
# 141        dead_leaves-mixed                nan                  128
# 142          stylegan-random                nan                  128
# 143        stylegan-highfreq                nan                  128
# 144      stat-spectrum_color                nan                  128
# 145            stat-spectrum                nan                  128
# 146     dead_leaves-textures                nan                  128
# 147      dead_leaves-squares                nan                  128
# 148     dead_leaves-oriented                nan                  128
# 149        dead_leaves-mixed                nan                  128
# 150  stat-spectrum_color_wmm                nan                  128
# 151  stat-spectrum_color_wmm                nan                  128
# 152  stat-spectrum_color_wmm                nan                  128
# 153  stat-spectrum_color_wmm                nan                  128
# 154  stat-spectrum_color_wmm                nan                  128
# 155  stat-spectrum_color_wmm                nan                  128
# 156  stat-spectrum_color_wmm                nan                  128
# 157  stat-spectrum_color_wmm                nan                  128
# 158  stat-spectrum_color_wmm                nan                  128
# 159  stat-spectrum_color_wmm                nan                  128
# 160                 stat-wmm                nan                  128
# 161                 stat-wmm                nan                  128
# 162                 stat-wmm                nan                  128
# 163                 stat-wmm                nan                  128
# 164                 stat-wmm                nan                  128
# 165                 stat-wmm                nan                  128
# 166                 stat-wmm                nan                  128
# 167                 stat-wmm                nan                  128
# 168                 stat-wmm                nan                  128
# 169                 stat-wmm                nan                  128
# 170                 stat-wmm                nan                  128
# 171                 stat-wmm                nan                  128
# 172                 stat-wmm                nan                  128
# 173                 stat-wmm                nan                  128
# 174                 stat-wmm                nan                  128
# 175  stat-spectrum_color_wmm                nan                  128
# 176  stat-spectrum_color_wmm                nan                  128
# 177  stat-spectrum_color_wmm                nan                  128
# 178  stat-spectrum_color_wmm                nan                  128
# 179  stat-spectrum_color_wmm                nan                  128
# 180  stat-spectrum_color_wmm                nan                  128
# 181  stat-spectrum_color_wmm                nan                  128
# 182  stat-spectrum_color_wmm                nan                  128
# 183  stat-spectrum_color_wmm                nan                  128
# 184  stat-spectrum_color_wmm                nan                  128
# 185                 stat-wmm                nan                  128
# 186                 stat-wmm                nan                  128
# 187                 stat-wmm                nan                  128
# 188                 stat-wmm                nan                  128
# 189                 stat-wmm                nan                  128
# 190                                         nan                  128
# 191                                         nan                  128
# 192                                         nan                  128
# 193                                         nan                  128
# 194                                         nan                  128
# 195                 stat-wmm                nan                  128
# 196                 stat-wmm                nan                  128
# 197                 stat-wmm                nan                  128
# 198                 stat-wmm                nan                  128
# 199                 stat-wmm                nan                  128
# 200  stat-spectrum_color_wmm                nan                  128
# 201  stat-spectrum_color_wmm                nan                  128
# 202  stat-spectrum_color_wmm                nan                  128
# 203  stat-spectrum_color_wmm                nan                  128
# 204  stat-spectrum_color_wmm                nan                  128
# 205  stat-spectrum_color_wmm                nan                  128
# 206  stat-spectrum_color_wmm                nan                  128
# 207  stat-spectrum_color_wmm                nan                  128
# 208  stat-spectrum_color_wmm                nan                  128
# 209  stat-spectrum_color_wmm                nan                  128
# 210  stat-spectrum_color_wmm                nan                  128
# 211  stat-spectrum_color_wmm                nan                  128
# 212  stat-spectrum_color_wmm                nan                  128
# 213  stat-spectrum_color_wmm                nan                  128
# 214  stat-spectrum_color_wmm                nan                  128
# 215  stat-spectrum_color_wmm                nan                  128
# 216  stat-spectrum_color_wmm                nan                  128
# 217  stat-spectrum_color_wmm                nan                  128
# 218  stat-spectrum_color_wmm                nan                  128
# 219  stat-spectrum_color_wmm                nan                  128
# 220  stat-spectrum_color_wmm                nan                  128
# 221  stat-spectrum_color_wmm                nan                  128
# 222  stat-spectrum_color_wmm                nan                  128
# 223  stat-spectrum_color_wmm                nan                  128
# 224  stat-spectrum_color_wmm                nan                  128
# 225                     None                nan                  128
# 226                     None                nan                  128
# 227                     None                nan                  128
# 228                     None                nan                  128
# 229                     None                nan                  128
# 230                     None                nan                  128
# 231                     None                nan                  128
# 232                     None                nan                  128
# 233                     None                nan                  128
# 234                     None                nan                  128
# 235                     None                nan                  128
# 236                     None                nan                  128
# 237                 stat-wmm                nan                  128
# 238                 stat-wmm                nan                  128
# 239                 stat-wmm                nan                  128
# 240                 stat-wmm                nan                  128
# 241                 stat-wmm                nan                  128
# 242                 stat-wmm                nan                  128
# 243                 stat-wmm                nan                  128
# 244                 stat-wmm                nan                  128
# 245                 stat-wmm                nan                  128
# 246                 stat-wmm                nan                  128
# 247                 stat-wmm                nan                  128
# 248                 stat-wmm                nan                  128
# 249                 stat-wmm                nan                  128
#
#     separate_noise_output
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# 5                     nan
# 6                     nan
# 7                     nan
# 8                     nan
# 9                     nan
# 10                    nan
# 11                    nan
# 12                    nan
# 13                    nan
# 14                    nan
# 15                    nan
# 16                    nan
# 17                    nan
# 18                    nan
# 19                    nan
# 20                    nan
# 21                    nan
# 22                    nan
# 23                    nan
# 24                    nan
# 25                    nan
# 26                    nan
# 27                    nan
# 28                    nan
# 29                    nan
# 30                    nan
# 31                    nan
# 32                    nan
# 33                    nan
# 34                    nan
# 35                    nan
# 36                    nan
# 37                    nan
# 38                    nan
# 39                    nan
# 40                    nan
# 41                    nan
# 42                    nan
# 43                    nan
# 44                    nan
# 45                    nan
# 46                    nan
# 47                    nan
# 48                    nan
# 49                    nan
# 50                    nan
# 51                    nan
# 52                    nan
# 53                    nan
# 54                    nan
# 55                    nan
# 56                    nan
# 57                    nan
# 58                    nan
# 59                    nan
# 60                    nan
# 61                    nan
# 62                    nan
# 63                    nan
# 64                    nan
# 65                    nan
# 66                    nan
# 67                    nan
# 68                    nan
# 69                    nan
# 70                    nan
# 71                    nan
# 72                    nan
# 73                    nan
# 74                    nan
# 75                    nan
# 76                    nan
# 77                    nan
# 78                    nan
# 79                    nan
# 80                    nan
# 81                    nan
# 82                    nan
# 83                    nan
# 84                    nan
# 85                    nan
# 86                    nan
# 87                    nan
# 88                    nan
# 89                    nan
# 90                    nan
# 91                    nan
# 92                    nan
# 93                    nan
# 94                    nan
# 95                    nan
# 96                    nan
# 97                    nan
# 98                    nan
# 99                    nan
# 100                   nan
# 101                   nan
# 102                   nan
# 103                   nan
# 104                   nan
# 105                   nan
# 106                   nan
# 107                   nan
# 108                   nan
# 109                   nan
# 110                   nan
# 111                   nan
# 112                   nan
# 113                   nan
# 114                   nan
# 115                   nan
# 116                   nan
# 117                   nan
# 118                   nan
# 119                   nan
# 120                   nan
# 121                   nan
# 122                   nan
# 123                   nan
# 124                   nan
# 125                   nan
# 126                   nan
# 127                   nan
# 128                   nan
# 129                   nan
# 130                   nan
# 131                   nan
# 132                   nan
# 133                   nan
# 134                   nan
# 135                   nan
# 136                   nan
# 137                   nan
# 138                   nan
# 139                   nan
# 140                   nan
# 141                   nan
# 142                   nan
# 143                   nan
# 144                   nan
# 145                   nan
# 146                   nan
# 147                   nan
# 148                   nan
# 149                   nan
# 150                   nan
# 151                   nan
# 152                   nan
# 153                   nan
# 154                   nan
# 155                   nan
# 156                   nan
# 157                   nan
# 158                   nan
# 159                   nan
# 160                   nan
# 161                   nan
# 162                   nan
# 163                   nan
# 164                   nan
# 165                   nan
# 166                   nan
# 167                   nan
# 168                   nan
# 169                   nan
# 170                   nan
# 171                   nan
# 172                   nan
# 173                   nan
# 174                   nan
# 175                   nan
# 176                   nan
# 177                   nan
# 178                   nan
# 179                   nan
# 180                   nan
# 181                   nan
# 182                   nan
# 183                   nan
# 184                   nan
# 185                   nan
# 186                   nan
# 187                   nan
# 188                   nan
# 189                   nan
# 190                   nan
# 191                   nan
# 192                   nan
# 193                   nan
# 194                   nan
# 195                   nan
# 196                   nan
# 197                   nan
# 198                   nan
# 199                   nan
# 200                   nan
# 201                   nan
# 202                   nan
# 203                   nan
# 204                   nan
# 205                   nan
# 206                   nan
# 207                   nan
# 208                   nan
# 209                   nan
# 210                   nan
# 211                   nan
# 212                   nan
# 213                   nan
# 214                   nan
# 215                   nan
# 216                   nan
# 217                   nan
# 218                   nan
# 219                   nan
# 220                   nan
# 221                   nan
# 222                   nan
# 223                   nan
# 224                   nan
# 225                   nan
# 226                   nan
# 227                   nan
# 228                   nan
# 229                   nan
# 230                   nan
# 231                   nan
# 232                   nan
# 233                   nan
# 234                   nan
# 235                   nan
# 236                   nan
# 237                   nan
# 238                   nan
# 239                   nan
# 240                   nan
# 241                   nan
# 242                   nan
# 243                   nan
# 244                   nan
# 245                   nan
# 246                   nan
# 247                   nan
# 248                   nan
# 249                   nan

# %%
df
# Out:
#     loss    setup epochs  dataset                          project optimizer  \
# 0     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 1     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 2     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 3     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 4     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 5     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 6     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 7     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 8     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 9     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 10    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 11    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 12    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 13    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 14    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 15    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 16    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 17    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 18    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 19    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 20    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 21    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 22    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 23    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 24    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 25    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 26    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 27    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 28    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 29    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 30    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 31    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 32    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 33    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 34    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 35    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 36    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 37    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 38    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 39    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 40    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 41    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 42    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 43    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 44    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 45    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 46    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 47    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 48    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 49    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 50    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 51    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 52    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 53    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 54    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 55    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 56    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 57    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 58    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 59    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 60    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 61    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 62    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 63    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 64    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 65    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 66    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 67    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 68    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 69    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 70    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 71    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 72    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 73    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 74    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 75    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 76    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 77    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 78    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 79    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 80    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 81    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 82    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 83    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 84    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 85    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 86    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 87    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 88    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 89    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 90    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 91    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 92    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 93    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 94    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 95    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 96    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 97    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 98    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 99    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 100   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 101   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 102   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 103   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 104   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 105   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 106   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 107   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 108   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 109   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 110   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 111   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 112   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 113   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 114   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 115   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 116   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 117   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 118   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 119   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 120   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 121   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 122   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 123   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 124   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 125   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 126   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 127   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 128   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 129   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 130   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 131   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 132   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 133   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 134   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 135   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 136   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 137   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 138   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 139   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 140   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 141   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 142  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 143  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 144  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 145  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 146  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 147  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 148  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 149  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 150  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 151  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 152  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 153  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 154  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 155  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 156  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 157  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 158  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 159  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 160  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 161  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 162  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 163  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 164  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 165  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 166  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 167  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 168  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 169  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 170  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 171  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 172  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 173  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 174  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 175  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 176  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 177  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 178  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 179  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 180  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 181  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 182  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 183  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 184  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 185  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 186  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 187  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 188  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 189  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 190  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 191  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 192  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 193  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 194  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 195  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 196  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 197  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 198  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 199  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 200  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 201  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 202  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 203  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 204  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 205  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 206  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 207  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 208  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 209  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 210  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 211  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 212  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 213  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 214  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 215  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 216  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 217  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 218  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 219  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 220  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 221  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 222  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 223  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 224  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 225  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 226  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 227  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 228  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 229  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 230  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 231  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 232  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 233  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 234  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 235  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 236  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 237  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 238  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 239  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 240  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 241  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 242  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 243  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
#
#     batch_size num_classes pretraining architecture  \
# 0        128.0        10.0       False     ResNet18
# 1        128.0        10.0       False     ResNet18
# 2        128.0        10.0       False     ResNet18
# 3        128.0        10.0       False     ResNet18
# 4        128.0        10.0       False     ResNet18
# 5        128.0        10.0       False     ResNet18
# 6        128.0        10.0       False     ResNet18
# 7        128.0        10.0       False     ResNet18
# 8        128.0        10.0       False     ResNet18
# 9        128.0        10.0       False     ResNet18
# 10       128.0        10.0       False     ResNet18
# 11       128.0        10.0       False     ResNet18
# 12       128.0        10.0       False     ResNet18
# 13       128.0        10.0       False     ResNet18
# 14       128.0        10.0        True     ResNet18
# 15       128.0        10.0       False     ResNet18
# 16       128.0        10.0        True     ResNet18
# 17       128.0        10.0        True     ResNet18
# 18       128.0        10.0       False     ResNet18
# 19       128.0        10.0       False     ResNet18
# 20       128.0        10.0       False     ResNet18
# 21       128.0        10.0        True     ResNet18
# 22       128.0        10.0       False     ResNet18
# 23       128.0        10.0       False     ResNet18
# 24       128.0        10.0        True     ResNet18
# 25       128.0        10.0        True     ResNet18
# 26       128.0        10.0        True     ResNet18
# 27       128.0        10.0        True     ResNet18
# 28       128.0        10.0        True     ResNet18
# 29       128.0        10.0       False     ResNet18
# 30       128.0        10.0       False     ResNet18
# 31       128.0        10.0       False     ResNet18
# 32       128.0        10.0        True     ResNet18
# 33       128.0        10.0       False     ResNet18
# 34       128.0        10.0       False     ResNet18
# 35       128.0        10.0        True     ResNet18
# 36       128.0        10.0        True     ResNet18
# 37       128.0        10.0        True     ResNet18
# 38       128.0        10.0       False     ResNet18
# 39       128.0        10.0       False     ResNet18
# 40       128.0        10.0        True     ResNet18
# 41       128.0        10.0       False     ResNet18
# 42       128.0        10.0        True     ResNet18
# 43       128.0        10.0       False     ResNet18
# 44       128.0        10.0        True     ResNet18
# 45       128.0        10.0        True     ResNet18
# 46       128.0        10.0        True     ResNet18
# 47       128.0        10.0       False     ResNet18
# 48       128.0        10.0        True     ResNet18
# 49       128.0        10.0        True     ResNet18
# 50       128.0        10.0        True     ResNet18
# 51       128.0        10.0       False     ResNet18
# 52       128.0        10.0        True     ResNet18
# 53       128.0        10.0        True     ResNet18
# 54       128.0        10.0       False     ResNet18
# 55       128.0        10.0       False     ResNet18
# 56       128.0        10.0       False     ResNet18
# 57       128.0        10.0       False     ResNet18
# 58       128.0        10.0       False     ResNet18
# 59       128.0        10.0        True     ResNet18
# 60       128.0        10.0        True     ResNet18
# 61       128.0        10.0        True     ResNet18
# 62       128.0        10.0        True     ResNet18
# 63       128.0        10.0        True     ResNet18
# 64       128.0        10.0       False     ResNet18
# 65       128.0        10.0       False     ResNet18
# 66       128.0        10.0       False     ResNet18
# 67       128.0        10.0        True     ResNet18
# 68       128.0        10.0        True     ResNet18
# 69       128.0        10.0        True     ResNet18
# 70       128.0        10.0        True     ResNet18
# 71       128.0        10.0        True     ResNet18
# 72       128.0        10.0        True     ResNet18
# 73       128.0        10.0        True     ResNet18
# 74       128.0        10.0       False     ResNet18
# 75       128.0        10.0       False     ResNet18
# 76       128.0        10.0       False     ResNet18
# 77       128.0        10.0       False     ResNet18
# 78       128.0        10.0       False     ResNet18
# 79       128.0        10.0       False     ResNet18
# 80       128.0        10.0       False     ResNet18
# 81       128.0        10.0       False     ResNet18
# 82       128.0        10.0        True     ResNet18
# 83       128.0        10.0        True     ResNet18
# 84       128.0        10.0        True     ResNet18
# 85       128.0        10.0        True     ResNet18
# 86       128.0        10.0        True     ResNet18
# 87       128.0        10.0        True     ResNet18
# 88       128.0        10.0        True     ResNet18
# 89       128.0        10.0        True     ResNet18
# 90       128.0        10.0        True     ResNet18
# 91       128.0        10.0        True     ResNet18
# 92       128.0        10.0       False     ResNet18
# 93       128.0        10.0       False     ResNet18
# 94       128.0        10.0       False     ResNet18
# 95       128.0        10.0       False     ResNet18
# 96       128.0        10.0       False     ResNet18
# 97       128.0        10.0       False     ResNet18
# 98       128.0        10.0       False     ResNet18
# 99       128.0        10.0       False     ResNet18
# 100      128.0        10.0        True     ResNet18
# 101      128.0        10.0        True     ResNet18
# 102      128.0        10.0        True     ResNet18
# 103      128.0        10.0        True     ResNet18
# 104      128.0        10.0        True     ResNet18
# 105      128.0        10.0        True     ResNet18
# 106      128.0        10.0        True     ResNet18
# 107      128.0        10.0        True     ResNet18
# 108      128.0        10.0        True     ResNet18
# 109      128.0        10.0        True     ResNet18
# 110      128.0        10.0       False     ResNet18
# 111      128.0        10.0       False     ResNet18
# 112      128.0        10.0       False     ResNet18
# 113      128.0        10.0       False     ResNet18
# 114      128.0        10.0       False     ResNet18
# 115      128.0        10.0       False     ResNet18
# 116      128.0        10.0       False     ResNet18
# 117      128.0        10.0       False     ResNet18
# 118      128.0        10.0        True     ResNet18
# 119      128.0        10.0        True     ResNet18
# 120      128.0        10.0        True     ResNet18
# 121      128.0        10.0        True     ResNet18
# 122      128.0        10.0        True     ResNet18
# 123      128.0        10.0        True     ResNet18
# 124      128.0        10.0        True     ResNet18
# 125      128.0        10.0        True     ResNet18
# 126      128.0        10.0        True     ResNet18
# 127      128.0        10.0        True     ResNet18
# 128      128.0        10.0        True     ResNet18
# 129      128.0        10.0       False     ResNet18
# 130      128.0        10.0       False     ResNet18
# 131      128.0        10.0       False     ResNet18
# 132      128.0        10.0       False     ResNet18
# 133      128.0        10.0       False     ResNet18
# 134      128.0        10.0       False     ResNet18
# 135      128.0        10.0       False     ResNet18
# 136      128.0        10.0       False     ResNet18
# 137      128.0        10.0        True     ResNet18
# 138      128.0        10.0        True     ResNet18
# 139      128.0        10.0        True     ResNet18
# 140      128.0        10.0        True     ResNet18
# 141      128.0        10.0        True     ResNet18
# 142      128.0        10.0       False     ResNet18
# 143      128.0        10.0       False     ResNet18
# 144      128.0        10.0       False     ResNet18
# 145      128.0        10.0       False     ResNet18
# 146      128.0        10.0       False     ResNet18
# 147      128.0        10.0       False     ResNet18
# 148      128.0        10.0       False     ResNet18
# 149      128.0        10.0       False     ResNet18
# 150      128.0        10.0       False     ResNet18
# 151      128.0        10.0       False     ResNet18
# 152      128.0        10.0       False     ResNet18
# 153      128.0        10.0       False     ResNet18
# 154      128.0        10.0       False     ResNet18
# 155      128.0        10.0        True     ResNet18
# 156      128.0        10.0        True     ResNet18
# 157      128.0        10.0        True     ResNet18
# 158      128.0        10.0        True     ResNet18
# 159      128.0        10.0        True     ResNet18
# 160      128.0        10.0        True     ResNet18
# 161      128.0        10.0        True     ResNet18
# 162      128.0        10.0        True     ResNet18
# 163      128.0        10.0        True     ResNet18
# 164      128.0        10.0        True     ResNet18
# 165      128.0        10.0       False     ResNet18
# 166      128.0        10.0       False     ResNet18
# 167      128.0        10.0       False     ResNet18
# 168      128.0        10.0       False     ResNet18
# 169      128.0        10.0       False     ResNet18
# 170      128.0        10.0       False     ResNet18
# 171      128.0        10.0       False     ResNet18
# 172      128.0        10.0       False     ResNet18
# 173      128.0        10.0       False     ResNet18
# 174      128.0        10.0       False     ResNet18
# 175      128.0        10.0       False     ResNet18
# 176      128.0        10.0       False     ResNet18
# 177      128.0        10.0       False     ResNet18
# 178      128.0        10.0       False     ResNet18
# 179      128.0        10.0       False     ResNet18
# 180      128.0        10.0        True     ResNet18
# 181      128.0        10.0        True     ResNet18
# 182      128.0        10.0        True     ResNet18
# 183      128.0        10.0        True     ResNet18
# 184      128.0        10.0        True     ResNet18
# 185      128.0        10.0        True     ResNet18
# 186      128.0        10.0        True     ResNet18
# 187      128.0        10.0        True     ResNet18
# 188      128.0        10.0        True     ResNet18
# 189      128.0        10.0        True     ResNet18
# 190      128.0        10.0       False     ResNet18
# 191      128.0        10.0       False     ResNet18
# 192      128.0        10.0       False     ResNet18
# 193      128.0        10.0       False     ResNet18
# 194      128.0        10.0       False     ResNet18
# 195        nan         nan       False     ResNet18
# 196        nan         nan       False     ResNet18
# 197        nan         nan       False     ResNet18
# 198        nan         nan       False     ResNet18
# 199        nan         nan       False     ResNet18
# 200        nan         nan       False     ResNet18
# 201        nan         nan       False     ResNet18
# 202        nan         nan       False     ResNet18
# 203        nan         nan       False     ResNet18
# 204        nan         nan       False     ResNet18
# 205        nan         nan        True     ResNet18
# 206        nan         nan        True     ResNet18
# 207        nan         nan        True     ResNet18
# 208        nan         nan        True     ResNet18
# 209        nan         nan        True     ResNet18
# 210        nan         nan        True     ResNet18
# 211        nan         nan        True     ResNet18
# 212        nan         nan        True     ResNet18
# 213        nan         nan        True     ResNet18
# 214        nan         nan        True     ResNet18
# 215        nan         nan        True     ResNet18
# 216        nan         nan        True     ResNet18
# 217        nan         nan        True     ResNet18
# 218        nan         nan        True     ResNet18
# 219        nan         nan        True     ResNet18
# 220        nan         nan        True     ResNet18
# 221        nan         nan        True     ResNet18
# 222        nan         nan        True     ResNet18
# 223        nan         nan        True     ResNet18
# 224        nan         nan        True     ResNet18
# 225        nan         nan       False     ResNet18
# 226        nan         nan       False     ResNet18
# 227        nan         nan       False     ResNet18
# 228        nan         nan       False     ResNet18
# 229        nan         nan       False     ResNet18
# 230        nan         nan       False     ResNet18
# 231        nan         nan       False     ResNet18
# 232        nan         nan       False     ResNet18
# 233        nan         nan       False     ResNet18
# 234        nan         nan       False     ResNet18
# 235        nan         nan       False     ResNet18
# 236        nan         nan       False     ResNet18
# 237        nan         nan       False     ResNet18
# 238        nan         nan        True     ResNet18
# 239        nan         nan        True     ResNet18
# 240        nan         nan        True     ResNet18
# 241        nan         nan        True     ResNet18
# 242        nan         nan        True     ResNet18
# 243        nan         nan        True     ResNet18
#
#                                  classes_list learning_rate classes_per_task  \
# 0    [[4, 9], [5, 6], [2, 7], [3, 8], [0, 1]]         0.003              2.0
# 1    [[1, 3], [0, 8], [6, 7], [4, 9], [2, 5]]         0.003              2.0
# 2    [[2, 3], [1, 8], [4, 9], [5, 7], [0, 6]]         0.003              2.0
# 3    [[1, 2], [3, 6], [7, 8], [0, 9], [4, 5]]         0.003              2.0
# 4    [[0, 7], [4, 5], [8, 9], [2, 6], [1, 3]]         0.003              2.0
# 5    [[3, 7], [0, 9], [1, 8], [2, 4], [5, 6]]         0.003              2.0
# 6    [[6, 7], [2, 9], [5, 8], [3, 4], [0, 1]]         0.003              2.0
# 7    [[3, 7], [0, 4], [6, 9], [1, 5], [2, 8]]         0.003              2.0
# 8    [[6, 7], [2, 5], [4, 9], [3, 8], [0, 1]]         0.003              2.0
# 9    [[3, 9], [1, 2], [0, 7], [5, 8], [4, 6]]         0.003              2.0
# 10   [[0, 2], [6, 9], [5, 7], [3, 8], [1, 4]]         0.003              2.0
# 11   [[5, 7], [2, 9], [3, 4], [6, 8], [0, 1]]         0.003              2.0
# 12   [[3, 5], [2, 8], [7, 9], [0, 6], [1, 4]]         0.003              2.0
# 13   [[4, 8], [5, 6], [7, 9], [0, 1], [2, 3]]         0.003              2.0
# 14   [[4, 5], [2, 9], [6, 7], [1, 3], [0, 8]]         0.003              2.0
# 15   [[0, 5], [1, 3], [8, 9], [2, 7], [4, 6]]         0.003              2.0
# 16   [[1, 7], [0, 2], [5, 6], [3, 8], [4, 9]]         0.003              2.0
# 17   [[1, 4], [3, 9], [6, 8], [5, 7], [0, 2]]         0.003              2.0
# 18   [[0, 6], [1, 5], [4, 9], [3, 7], [2, 8]]         0.003              2.0
# 19   [[1, 6], [7, 9], [5, 8], [3, 4], [0, 2]]         0.003              2.0
# 20   [[5, 7], [4, 8], [0, 9], [1, 3], [2, 6]]         0.003              2.0
# 21   [[0, 5], [4, 8], [3, 7], [1, 2], [6, 9]]         0.003              2.0
# 22   [[1, 2], [7, 8], [5, 6], [0, 9], [3, 4]]         0.003              2.0
# 23   [[0, 5], [3, 7], [1, 9], [2, 6], [4, 8]]         0.003              2.0
# 24   [[1, 5], [6, 7], [0, 2], [3, 8], [4, 9]]         0.003              2.0
# 25   [[3, 4], [0, 8], [5, 7], [2, 6], [1, 9]]         0.003              2.0
# 26   [[1, 3], [4, 9], [2, 6], [5, 8], [0, 7]]         0.003              2.0
# 27   [[0, 6], [1, 4], [3, 5], [2, 7], [8, 9]]         0.003              2.0
# 28   [[1, 5], [3, 8], [0, 4], [2, 7], [6, 9]]         0.003              2.0
# 29   [[1, 5], [0, 9], [2, 8], [6, 7], [3, 4]]         0.003              2.0
# 30   [[1, 3], [8, 9], [2, 5], [4, 6], [0, 7]]         0.003              2.0
# 31   [[5, 6], [3, 9], [0, 7], [1, 8], [2, 4]]         0.003              2.0
# 32   [[1, 5], [3, 7], [4, 9], [0, 8], [2, 6]]         0.003              2.0
# 33   [[5, 6], [4, 8], [7, 9], [0, 3], [1, 2]]         0.003              2.0
# 34   [[3, 6], [2, 7], [0, 5], [1, 8], [4, 9]]         0.003              2.0
# 35   [[2, 7], [0, 9], [1, 5], [6, 8], [3, 4]]         0.003              2.0
# 36   [[0, 5], [7, 9], [4, 8], [1, 3], [2, 6]]         0.003              2.0
# 37   [[3, 5], [8, 9], [2, 6], [1, 4], [0, 7]]         0.003              2.0
# 38   [[2, 8], [0, 9], [4, 5], [3, 7], [1, 6]]         0.003              2.0
# 39   [[2, 9], [3, 4], [0, 8], [5, 6], [1, 7]]         0.003              2.0
# 40   [[1, 9], [2, 3], [6, 7], [4, 8], [0, 5]]         0.003              2.0
# 41   [[6, 8], [2, 5], [0, 4], [3, 9], [1, 7]]         0.003              2.0
# 42   [[5, 8], [0, 7], [2, 4], [3, 9], [1, 6]]         0.003              2.0
# 43   [[3, 6], [1, 7], [4, 5], [0, 9], [2, 8]]         0.003              2.0
# 44   [[5, 7], [3, 6], [4, 8], [0, 1], [2, 9]]         0.003              2.0
# 45   [[6, 9], [4, 8], [0, 3], [1, 2], [5, 7]]         0.003              2.0
# 46   [[1, 2], [8, 9], [3, 4], [0, 6], [5, 7]]         0.003              2.0
# 47   [[4, 6], [0, 9], [1, 3], [2, 7], [5, 8]]         0.003              2.0
# 48   [[3, 6], [2, 7], [1, 9], [0, 8], [4, 5]]         0.003              2.0
# 49   [[1, 7], [0, 4], [2, 5], [3, 9], [6, 8]]         0.003              2.0
# 50   [[2, 5], [0, 7], [1, 6], [8, 9], [3, 4]]         0.003              2.0
# 51   [[1, 6], [0, 8], [7, 9], [2, 5], [3, 4]]         0.003              2.0
# 52   [[0, 9], [2, 6], [3, 5], [4, 7], [1, 8]]         0.003              2.0
# 53   [[3, 7], [4, 5], [0, 6], [8, 9], [1, 2]]         0.003              2.0
# 54   [[6, 8], [3, 9], [2, 4], [0, 5], [1, 7]]         0.003              2.0
# 55   [[1, 8], [4, 9], [0, 3], [2, 5], [6, 7]]         0.003              2.0
# 56   [[2, 4], [1, 9], [0, 6], [7, 8], [3, 5]]         0.003              2.0
# 57   [[1, 6], [3, 4], [2, 5], [0, 7], [8, 9]]         0.003              2.0
# 58   [[1, 7], [0, 3], [2, 4], [8, 9], [5, 6]]         0.003              2.0
# 59   [[4, 6], [1, 5], [3, 7], [2, 8], [0, 9]]         0.003              2.0
# 60   [[1, 9], [2, 5], [0, 3], [4, 6], [7, 8]]         0.003              2.0
# 61   [[4, 5], [3, 8], [1, 6], [7, 9], [0, 2]]         0.003              2.0
# 62   [[2, 8], [6, 9], [4, 5], [1, 7], [0, 3]]         0.003              2.0
# 63   [[5, 9], [4, 7], [0, 1], [3, 8], [2, 6]]         0.003              2.0
# 64   [[2, 7], [6, 8], [1, 9], [0, 5], [3, 4]]         0.003              2.0
# 65   [[4, 6], [8, 9], [1, 5], [2, 7], [0, 3]]         0.003              2.0
# 66   [[0, 9], [6, 8], [1, 7], [3, 4], [2, 5]]         0.003              2.0
# 67   [[3, 5], [8, 9], [2, 6], [0, 1], [4, 7]]         0.003              2.0
# 68   [[5, 8], [7, 9], [2, 3], [0, 6], [1, 4]]         0.003              2.0
# 69   [[6, 4], [3, 1], [8, 5], [0, 9], [7, 2]]         0.003              2.0
# 70   [[8, 1], [7, 4], [3, 2], [9, 0], [6, 5]]         0.003              2.0
# 71   [[0, 3], [8, 2], [1, 5], [7, 4], [6, 9]]         0.003              2.0
# 72   [[1, 4], [8, 0], [9, 6], [7, 3], [5, 2]]         0.003              2.0
# 73   [[9, 6], [7, 1], [2, 8], [5, 4], [0, 3]]         0.003              2.0
# 74   [[5, 3], [6, 2], [1, 8], [0, 4], [9, 7]]         0.003              2.0
# 75   [[7, 6], [9, 1], [3, 4], [8, 5], [0, 2]]         0.003              2.0
# 76   [[8, 7], [3, 9], [0, 6], [2, 5], [1, 4]]         0.003              2.0
# 77   [[8, 7], [9, 4], [3, 1], [2, 0], [5, 6]]         0.003              2.0
# 78   [[1, 2], [0, 5], [7, 8], [4, 9], [3, 6]]         0.003              2.0
# 79   [[6, 1], [7, 9], [5, 4], [3, 2], [8, 0]]         0.003              2.0
# 80   [[5, 2], [1, 3], [7, 4], [8, 9], [6, 0]]         0.003              2.0
# 81   [[2, 1], [7, 9], [4, 8], [0, 6], [3, 5]]         0.003              2.0
# 82   [[2, 6], [4, 8], [0, 5], [7, 9], [1, 3]]         0.003              2.0
# 83   [[6, 2], [9, 7], [8, 3], [5, 4], [0, 1]]         0.003              2.0
# 84   [[2, 0], [6, 8], [4, 5], [1, 3], [9, 7]]         0.003              2.0
# 85   [[7, 0], [3, 4], [8, 6], [9, 2], [5, 1]]         0.003              2.0
# 86   [[8, 1], [3, 7], [2, 6], [0, 5], [9, 4]]         0.003              2.0
# 87   [[2, 4], [3, 0], [1, 5], [7, 6], [9, 8]]         0.003              2.0
# 88   [[6, 1], [7, 3], [8, 5], [2, 4], [0, 9]]         0.003              2.0
# 89   [[0, 1], [8, 4], [7, 3], [5, 2], [9, 6]]         0.003              2.0
# 90   [[2, 5], [8, 1], [6, 0], [3, 9], [4, 7]]         0.003              2.0
# 91   [[3, 8], [6, 0], [7, 9], [4, 5], [1, 2]]         0.003              2.0
# 92   [[6, 8], [5, 4], [0, 3], [1, 2], [9, 7]]         0.003              2.0
# 93   [[4, 0], [3, 6], [5, 8], [9, 2], [1, 7]]         0.003              2.0
# 94   [[6, 0], [3, 7], [5, 1], [8, 2], [4, 9]]         0.003              2.0
# 95   [[8, 0], [9, 7], [3, 1], [2, 6], [4, 5]]         0.003              2.0
# 96   [[3, 1], [6, 0], [9, 8], [5, 7], [2, 4]]         0.003              2.0
# 97   [[7, 4], [0, 6], [1, 2], [8, 3], [9, 5]]         0.003              2.0
# 98   [[4, 7], [6, 8], [2, 1], [5, 3], [9, 0]]         0.003              2.0
# 99   [[1, 4], [2, 0], [8, 5], [9, 7], [3, 6]]         0.003              2.0
# 100  [[8, 3], [4, 5], [2, 7], [1, 6], [9, 0]]         0.003              2.0
# 101  [[1, 5], [9, 8], [7, 6], [4, 0], [2, 3]]         0.003              2.0
# 102  [[1, 9], [5, 2], [4, 6], [3, 8], [0, 7]]         0.003              2.0
# 103  [[5, 3], [6, 1], [0, 4], [2, 8], [7, 9]]         0.003              2.0
# 104  [[5, 0], [6, 4], [2, 9], [1, 3], [8, 7]]         0.003              2.0
# 105  [[2, 6], [1, 9], [4, 5], [7, 8], [0, 3]]         0.003              2.0
# 106  [[3, 5], [8, 1], [0, 7], [6, 9], [2, 4]]         0.003              2.0
# 107  [[7, 5], [3, 0], [1, 9], [6, 4], [8, 2]]         0.003              2.0
# 108  [[3, 7], [4, 8], [9, 2], [0, 5], [1, 6]]         0.003              2.0
# 109  [[2, 1], [7, 8], [0, 9], [3, 6], [5, 4]]         0.003              2.0
# 110  [[5, 6], [3, 2], [9, 7], [0, 4], [8, 1]]         0.003              2.0
# 111  [[9, 6], [7, 2], [4, 0], [1, 3], [8, 5]]         0.003              2.0
# 112  [[6, 9], [2, 8], [0, 1], [7, 3], [5, 4]]         0.003              2.0
# 113  [[3, 2], [7, 6], [8, 5], [0, 1], [4, 9]]         0.003              2.0
# 114  [[0, 1], [5, 4], [9, 2], [7, 6], [8, 3]]         0.003              2.0
# 115  [[5, 8], [1, 4], [9, 3], [2, 7], [0, 6]]         0.003              2.0
# 116  [[5, 2], [0, 1], [8, 7], [3, 9], [4, 6]]         0.003              2.0
# 117  [[2, 6], [0, 4], [1, 9], [7, 8], [3, 5]]         0.003              2.0
# 118  [[9, 8], [0, 1], [2, 3], [4, 7], [5, 6]]         0.003              2.0
# 119  [[6, 5], [9, 0], [4, 3], [7, 2], [8, 1]]         0.003              2.0
# 120  [[7, 9], [8, 1], [3, 0], [6, 2], [4, 5]]         0.003              2.0
# 121  [[4, 6], [3, 2], [1, 0], [7, 8], [5, 9]]         0.003              2.0
# 122  [[0, 5], [6, 3], [9, 8], [7, 4], [2, 1]]         0.003              2.0
# 123  [[2, 6], [8, 7], [0, 5], [1, 3], [9, 4]]         0.003              2.0
# 124  [[2, 9], [0, 8], [1, 5], [7, 3], [4, 6]]         0.003              2.0
# 125  [[5, 0], [1, 7], [8, 9], [6, 3], [4, 2]]         0.003              2.0
# 126  [[1, 3], [2, 9], [6, 4], [0, 7], [5, 8]]         0.003              2.0
# 127  [[1, 0], [3, 2], [4, 6], [7, 5], [8, 9]]         0.003              2.0
# 128  [[6, 0], [8, 9], [7, 5], [3, 2], [4, 1]]         0.003              2.0
# 129  [[2, 5], [0, 4], [8, 9], [3, 7], [6, 1]]         0.003              2.0
# 130  [[0, 7], [2, 1], [5, 8], [6, 3], [4, 9]]         0.003              2.0
# 131  [[1, 4], [2, 8], [9, 3], [0, 7], [5, 6]]         0.003              2.0
# 132  [[3, 7], [2, 8], [0, 6], [4, 5], [9, 1]]         0.003              2.0
# 133  [[3, 0], [8, 1], [6, 9], [5, 2], [7, 4]]         0.003              2.0
# 134  [[3, 4], [5, 1], [7, 0], [8, 9], [6, 2]]         0.003              2.0
# 135  [[2, 3], [5, 4], [1, 0], [7, 9], [8, 6]]         0.003              2.0
# 136  [[7, 0], [5, 4], [9, 2], [3, 6], [1, 8]]         0.003              2.0
# 137  [[1, 5], [8, 4], [6, 7], [3, 9], [2, 0]]         0.003              2.0
# 138  [[1, 8], [4, 2], [0, 5], [9, 6], [3, 7]]         0.003              2.0
# 139  [[6, 3], [2, 0], [9, 5], [4, 7], [8, 1]]         0.003              2.0
# 140  [[1, 7], [3, 0], [5, 2], [6, 4], [8, 9]]         0.003              2.0
# 141  [[9, 6], [7, 1], [0, 4], [8, 5], [2, 3]]         0.003              2.0
# 142  [[0, 7], [2, 4], [8, 3], [6, 9], [5, 1]]         0.003              2.0
# 143  [[5, 3], [6, 4], [0, 8], [7, 1], [9, 2]]         0.003              2.0
# 144  [[0, 1], [5, 6], [4, 8], [3, 7], [9, 2]]         0.003              2.0
# 145  [[1, 8], [9, 3], [4, 7], [0, 6], [5, 2]]         0.003              2.0
# 146  [[5, 3], [8, 4], [9, 6], [1, 7], [2, 0]]         0.003              2.0
# 147  [[4, 6], [7, 5], [2, 0], [1, 8], [3, 9]]         0.003              2.0
# 148  [[5, 2], [3, 9], [6, 8], [0, 1], [4, 7]]         0.003              2.0
# 149  [[8, 0], [5, 2], [6, 3], [7, 4], [9, 1]]         0.003              2.0
# 150  [[3, 7], [8, 2], [5, 9], [0, 6], [1, 4]]         0.003              2.0
# 151  [[2, 5], [7, 0], [6, 4], [3, 9], [8, 1]]         0.003              2.0
# 152  [[0, 9], [3, 5], [2, 1], [6, 7], [4, 8]]         0.003              2.0
# 153  [[2, 8], [9, 0], [3, 5], [6, 7], [4, 1]]         0.003              2.0
# 154  [[0, 6], [5, 1], [8, 7], [4, 2], [3, 9]]         0.003              2.0
# 155  [[5, 4], [1, 6], [3, 0], [8, 9], [2, 7]]         0.003              2.0
# 156  [[0, 8], [6, 3], [5, 1], [7, 9], [4, 2]]         0.003              2.0
# 157  [[8, 0], [3, 4], [9, 2], [6, 1], [5, 7]]         0.003              2.0
# 158  [[5, 6], [3, 8], [9, 0], [2, 4], [7, 1]]         0.003              2.0
# 159  [[1, 0], [6, 7], [3, 2], [9, 8], [5, 4]]         0.003              2.0
# 160  [[6, 0], [7, 8], [9, 2], [4, 1], [3, 5]]         0.003              2.0
# 161  [[0, 9], [1, 7], [3, 8], [5, 4], [2, 6]]         0.003              2.0
# 162  [[5, 4], [9, 0], [1, 8], [2, 7], [3, 6]]         0.003              2.0
# 163  [[8, 7], [0, 6], [3, 9], [1, 5], [2, 4]]         0.003              2.0
# 164  [[6, 4], [8, 5], [1, 2], [7, 0], [9, 3]]         0.003              2.0
# 165  [[0, 2], [8, 5], [4, 6], [1, 9], [3, 7]]         0.003              2.0
# 166  [[4, 6], [8, 2], [3, 9], [1, 5], [7, 0]]         0.003              2.0
# 167  [[6, 1], [0, 3], [7, 2], [8, 4], [5, 9]]         0.003              2.0
# 168  [[9, 3], [4, 7], [8, 0], [2, 1], [6, 5]]         0.003              2.0
# 169  [[4, 6], [0, 5], [7, 8], [2, 9], [3, 1]]         0.003              2.0
# 170  [[6, 8], [0, 5], [4, 7], [3, 9], [1, 2]]         0.003              2.0
# 171  [[1, 3], [4, 7], [5, 8], [6, 9], [2, 0]]         0.003              2.0
# 172  [[3, 0], [2, 5], [7, 6], [4, 1], [8, 9]]         0.003              2.0
# 173  [[4, 5], [8, 3], [9, 2], [7, 1], [6, 0]]         0.003              2.0
# 174  [[6, 9], [1, 2], [0, 8], [7, 3], [4, 5]]         0.003              2.0
# 175  [[2, 9], [3, 6], [1, 0], [4, 8], [7, 5]]         0.003              2.0
# 176  [[8, 4], [3, 6], [0, 7], [9, 1], [2, 5]]         0.003              2.0
# 177  [[4, 8], [5, 1], [3, 6], [0, 2], [9, 7]]         0.003              2.0
# 178  [[8, 6], [1, 2], [5, 4], [0, 7], [9, 3]]         0.003              2.0
# 179  [[8, 1], [9, 7], [5, 6], [4, 3], [0, 2]]         0.003              2.0
# 180  [[0, 6], [9, 1], [7, 8], [2, 4], [3, 5]]         0.003              2.0
# 181  [[1, 8], [0, 9], [3, 7], [2, 4], [5, 6]]         0.003              2.0
# 182  [[3, 7], [8, 0], [6, 1], [4, 5], [9, 2]]         0.003              2.0
# 183  [[9, 8], [0, 1], [5, 2], [7, 4], [6, 3]]         0.003              2.0
# 184  [[4, 5], [0, 7], [9, 1], [2, 6], [8, 3]]         0.003              2.0
# ...
# 118      dead_leaves-squares                nan                  128
# 119      dead_leaves-squares                nan                  128
# 120      dead_leaves-squares                nan                  128
# 121      dead_leaves-squares                nan                  128
# 122      dead_leaves-squares                nan                  128
# 123      dead_leaves-squares                nan                  128
# 124     dead_leaves-oriented                nan                  128
# 125     dead_leaves-oriented                nan                  128
# 126     dead_leaves-oriented                nan                  128
# 127     dead_leaves-oriented                nan                  128
# 128     dead_leaves-oriented                nan                  128
# 129     dead_leaves-oriented                nan                  128
# 130     dead_leaves-oriented                nan                  128
# 131     dead_leaves-oriented                nan                  128
# 132     dead_leaves-oriented                nan                  128
# 133        dead_leaves-mixed                nan                  128
# 134        dead_leaves-mixed                nan                  128
# 135        dead_leaves-mixed                nan                  128
# 136        dead_leaves-mixed                nan                  128
# 137        dead_leaves-mixed                nan                  128
# 138        dead_leaves-mixed                nan                  128
# 139        dead_leaves-mixed                nan                  128
# 140        dead_leaves-mixed                nan                  128
# 141        dead_leaves-mixed                nan                  128
# 142          stylegan-random                nan                  128
# 143        stylegan-highfreq                nan                  128
# 144      stat-spectrum_color                nan                  128
# 145            stat-spectrum                nan                  128
# 146     dead_leaves-textures                nan                  128
# 147      dead_leaves-squares                nan                  128
# 148     dead_leaves-oriented                nan                  128
# 149        dead_leaves-mixed                nan                  128
# 150  stat-spectrum_color_wmm                nan                  128
# 151  stat-spectrum_color_wmm                nan                  128
# 152  stat-spectrum_color_wmm                nan                  128
# 153  stat-spectrum_color_wmm                nan                  128
# 154  stat-spectrum_color_wmm                nan                  128
# 155  stat-spectrum_color_wmm                nan                  128
# 156  stat-spectrum_color_wmm                nan                  128
# 157  stat-spectrum_color_wmm                nan                  128
# 158  stat-spectrum_color_wmm                nan                  128
# 159  stat-spectrum_color_wmm                nan                  128
# 160                 stat-wmm                nan                  128
# 161                 stat-wmm                nan                  128
# 162                 stat-wmm                nan                  128
# 163                 stat-wmm                nan                  128
# 164                 stat-wmm                nan                  128
# 165                 stat-wmm                nan                  128
# 166                 stat-wmm                nan                  128
# 167                 stat-wmm                nan                  128
# 168                 stat-wmm                nan                  128
# 169                 stat-wmm                nan                  128
# 170                 stat-wmm                nan                  128
# 171                 stat-wmm                nan                  128
# 172                 stat-wmm                nan                  128
# 173                 stat-wmm                nan                  128
# 174                 stat-wmm                nan                  128
# 175  stat-spectrum_color_wmm                nan                  128
# 176  stat-spectrum_color_wmm                nan                  128
# 177  stat-spectrum_color_wmm                nan                  128
# 178  stat-spectrum_color_wmm                nan                  128
# 179  stat-spectrum_color_wmm                nan                  128
# 180  stat-spectrum_color_wmm                nan                  128
# 181  stat-spectrum_color_wmm                nan                  128
# 182  stat-spectrum_color_wmm                nan                  128
# 183  stat-spectrum_color_wmm                nan                  128
# 184  stat-spectrum_color_wmm                nan                  128
# 185                 stat-wmm                nan                  128
# 186                 stat-wmm                nan                  128
# 187                 stat-wmm                nan                  128
# 188                 stat-wmm                nan                  128
# 189                 stat-wmm                nan                  128
# 190                                         nan                  128
# 191                                         nan                  128
# 192                                         nan                  128
# 193                                         nan                  128
# 194                                         nan                  128
# 195                 stat-wmm                nan                  128
# 196                 stat-wmm                nan                  128
# 197                 stat-wmm                nan                  128
# 198                 stat-wmm                nan                  128
# 199                 stat-wmm                nan                  128
# 200  stat-spectrum_color_wmm                nan                  128
# 201  stat-spectrum_color_wmm                nan                  128
# 202  stat-spectrum_color_wmm                nan                  128
# 203  stat-spectrum_color_wmm                nan                  128
# 204  stat-spectrum_color_wmm                nan                  128
# 205  stat-spectrum_color_wmm                nan                  128
# 206  stat-spectrum_color_wmm                nan                  128
# 207  stat-spectrum_color_wmm                nan                  128
# 208  stat-spectrum_color_wmm                nan                  128
# 209  stat-spectrum_color_wmm                nan                  128
# 210  stat-spectrum_color_wmm                nan                  128
# 211  stat-spectrum_color_wmm                nan                  128
# 212  stat-spectrum_color_wmm                nan                  128
# 213  stat-spectrum_color_wmm                nan                  128
# 214  stat-spectrum_color_wmm                nan                  128
# 215  stat-spectrum_color_wmm                nan                  128
# 216  stat-spectrum_color_wmm                nan                  128
# 217  stat-spectrum_color_wmm                nan                  128
# 218  stat-spectrum_color_wmm                nan                  128
# 219  stat-spectrum_color_wmm                nan                  128
# 220  stat-spectrum_color_wmm                nan                  128
# 221  stat-spectrum_color_wmm                nan                  128
# 222  stat-spectrum_color_wmm                nan                  128
# 223  stat-spectrum_color_wmm                nan                  128
# 224  stat-spectrum_color_wmm                nan                  128
# 225                     None                nan                  128
# 226                     None                nan                  128
# 227                     None                nan                  128
# 228                     None                nan                  128
# 229                     None                nan                  128
# 230                     None                nan                  128
# 231                     None                nan                  128
# 232                     None                nan                  128
# 233                     None                nan                  128
# 234                     None                nan                  128
# 235                     None                nan                  128
# 236                     None                nan                  128
# 237                 stat-wmm                nan                  128
# 238                 stat-wmm                nan                  128
# 239                 stat-wmm                nan                  128
# 240                 stat-wmm                nan                  128
# 241                 stat-wmm                nan                  128
# 242                 stat-wmm                nan                  128
# 243                 stat-wmm                nan                  128
#
#     separate_noise_output
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# 5                     nan
# 6                     nan
# 7                     nan
# 8                     nan
# 9                     nan
# 10                    nan
# 11                    nan
# 12                    nan
# 13                    nan
# 14                    nan
# 15                    nan
# 16                    nan
# 17                    nan
# 18                    nan
# 19                    nan
# 20                    nan
# 21                    nan
# 22                    nan
# 23                    nan
# 24                    nan
# 25                    nan
# 26                    nan
# 27                    nan
# 28                    nan
# 29                    nan
# 30                    nan
# 31                    nan
# 32                    nan
# 33                    nan
# 34                    nan
# 35                    nan
# 36                    nan
# 37                    nan
# 38                    nan
# 39                    nan
# 40                    nan
# 41                    nan
# 42                    nan
# 43                    nan
# 44                    nan
# 45                    nan
# 46                    nan
# 47                    nan
# 48                    nan
# 49                    nan
# 50                    nan
# 51                    nan
# 52                    nan
# 53                    nan
# 54                    nan
# 55                    nan
# 56                    nan
# 57                    nan
# 58                    nan
# 59                    nan
# 60                    nan
# 61                    nan
# 62                    nan
# 63                    nan
# 64                    nan
# 65                    nan
# 66                    nan
# 67                    nan
# 68                    nan
# 69                    nan
# 70                    nan
# 71                    nan
# 72                    nan
# 73                    nan
# 74                    nan
# 75                    nan
# 76                    nan
# 77                    nan
# 78                    nan
# 79                    nan
# 80                    nan
# 81                    nan
# 82                    nan
# 83                    nan
# 84                    nan
# 85                    nan
# 86                    nan
# 87                    nan
# 88                    nan
# 89                    nan
# 90                    nan
# 91                    nan
# 92                    nan
# 93                    nan
# 94                    nan
# 95                    nan
# 96                    nan
# 97                    nan
# 98                    nan
# 99                    nan
# 100                   nan
# 101                   nan
# 102                   nan
# 103                   nan
# 104                   nan
# 105                   nan
# 106                   nan
# 107                   nan
# 108                   nan
# 109                   nan
# 110                   nan
# 111                   nan
# 112                   nan
# 113                   nan
# 114                   nan
# 115                   nan
# 116                   nan
# 117                   nan
# 118                   nan
# 119                   nan
# 120                   nan
# 121                   nan
# 122                   nan
# 123                   nan
# 124                   nan
# 125                   nan
# 126                   nan
# 127                   nan
# 128                   nan
# 129                   nan
# 130                   nan
# 131                   nan
# 132                   nan
# 133                   nan
# 134                   nan
# 135                   nan
# 136                   nan
# 137                   nan
# 138                   nan
# 139                   nan
# 140                   nan
# 141                   nan
# 142                   nan
# 143                   nan
# 144                   nan
# 145                   nan
# 146                   nan
# 147                   nan
# 148                   nan
# 149                   nan
# 150                   nan
# 151                   nan
# 152                   nan
# 153                   nan
# 154                   nan
# 155                   nan
# 156                   nan
# 157                   nan
# 158                   nan
# 159                   nan
# 160                   nan
# 161                   nan
# 162                   nan
# 163                   nan
# 164                   nan
# 165                   nan
# 166                   nan
# 167                   nan
# 168                   nan
# 169                   nan
# 170                   nan
# 171                   nan
# 172                   nan
# 173                   nan
# 174                   nan
# 175                   nan
# 176                   nan
# 177                   nan
# 178                   nan
# 179                   nan
# 180                   nan
# 181                   nan
# 182                   nan
# 183                   nan
# 184                   nan
# 185                   nan
# 186                   nan
# 187                   nan
# 188                   nan
# 189                   nan
# 190                   nan
# 191                   nan
# 192                   nan
# 193                   nan
# 194                   nan
# 195                   nan
# 196                   nan
# 197                   nan
# 198                   nan
# 199                   nan
# 200                   nan
# 201                   nan
# 202                   nan
# 203                   nan
# 204                   nan
# 205                   nan
# 206                   nan
# 207                   nan
# 208                   nan
# 209                   nan
# 210                   nan
# 211                   nan
# 212                   nan
# 213                   nan
# 214                   nan
# 215                   nan
# 216                   nan
# 217                   nan
# 218                   nan
# 219                   nan
# 220                   nan
# 221                   nan
# 222                   nan
# 223                   nan
# 224                   nan
# 225                   nan
# 226                   nan
# 227                   nan
# 228                   nan
# 229                   nan
# 230                   nan
# 231                   nan
# 232                   nan
# 233                   nan
# 234                   nan
# 235                   nan
# 236                   nan
# 237                   nan
# 238                   nan
# 239                   nan
# 240                   nan
# 241                   nan
# 242                   nan
# 243                   nan

# %%
df = df.iloc[0:194]

# %%
df
# Out:
#     loss    setup epochs  dataset                          project optimizer  \
# 0     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 1     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 2     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 3     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 4     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 5     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 6     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 7     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 8     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 9     CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 10    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 11    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 12    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 13    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 14    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 15    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 16    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 17    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 18    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 19    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 20    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 21    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 22    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 23    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 24    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 25    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 26    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 27    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 28    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 29    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 30    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 31    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 32    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 33    CE   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 34    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 35    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 36    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 37    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 38    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 39    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 40    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 41    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 42    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 43    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 44    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 45    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 46    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 47    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 48    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 49    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 50    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 51    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 52    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 53    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 54    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 55    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 56    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 57    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 58    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 59    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 60    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 61    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 62    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 63    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 64    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 65    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 66    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 67    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 68    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 69    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 70    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 71    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 72    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 73    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 74    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 75    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 76    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 77    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 78    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 79    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 80    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 81    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 82    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 83    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 84    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 85    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 86    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 87    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 88    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 89    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 90    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 91    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 92    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 93    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 94    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 95    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 96    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 97    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 98    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 99    CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 100   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 101   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 102   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 103   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 104   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 105   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 106   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 107   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 108   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 109   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 110   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 111   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 112   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 113   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 114   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 115   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 116   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 117   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 118   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 119   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 120   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 121   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 122   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 123   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 124   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 125   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 126   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 127   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 128   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 129   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 130   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 131   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 132   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 133   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 134   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 135   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 136   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 137   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 138   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 139   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 140   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 141   CE   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 142  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 143  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 144  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 145  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 146  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 147  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 148  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 149  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 150  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 151  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 152  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 153  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 154  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 155  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 156  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 157  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 158  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 159  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 160  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 161  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 162  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 163  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 164  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 165  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 166  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 167  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 168  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 169  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 170  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 171  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 172  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 173  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 174  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 175  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 176  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 177  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 178  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 179  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 180  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 181  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 182  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 183  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 184  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       SGD
# 185  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 186  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 187  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 188  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 189  nan   taskIL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL      None
# 190  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 191  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 192  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 193  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 194  nan   taskIL     20  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 195  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 196  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 197  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 198  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 199  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 200  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 201  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 202  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 203  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 204  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 205  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 206  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 207  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 208  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 209  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 210  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 211  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 212  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 213  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 214  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 215  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 216  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 217  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 218  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 219  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 220  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 221  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 222  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 223  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 224  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 225  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 226  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 227  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 228  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 229  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 230  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 231  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 232  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 233  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 234  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 235  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 236  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 237  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 238  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 239  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 240  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 241  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 242  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
# 243  nan  task IL      5  CIFAR10  rehersal ResNet CIFAR10 Task IL       nan
#
#     batch_size num_classes pretraining architecture  \
# 0        128.0        10.0       False     ResNet18
# 1        128.0        10.0       False     ResNet18
# 2        128.0        10.0       False     ResNet18
# 3        128.0        10.0       False     ResNet18
# 4        128.0        10.0       False     ResNet18
# 5        128.0        10.0       False     ResNet18
# 6        128.0        10.0       False     ResNet18
# 7        128.0        10.0       False     ResNet18
# 8        128.0        10.0       False     ResNet18
# 9        128.0        10.0       False     ResNet18
# 10       128.0        10.0       False     ResNet18
# 11       128.0        10.0       False     ResNet18
# 12       128.0        10.0       False     ResNet18
# 13       128.0        10.0       False     ResNet18
# 14       128.0        10.0        True     ResNet18
# 15       128.0        10.0       False     ResNet18
# 16       128.0        10.0        True     ResNet18
# 17       128.0        10.0        True     ResNet18
# 18       128.0        10.0       False     ResNet18
# 19       128.0        10.0       False     ResNet18
# 20       128.0        10.0       False     ResNet18
# 21       128.0        10.0        True     ResNet18
# 22       128.0        10.0       False     ResNet18
# 23       128.0        10.0       False     ResNet18
# 24       128.0        10.0        True     ResNet18
# 25       128.0        10.0        True     ResNet18
# 26       128.0        10.0        True     ResNet18
# 27       128.0        10.0        True     ResNet18
# 28       128.0        10.0        True     ResNet18
# 29       128.0        10.0       False     ResNet18
# 30       128.0        10.0       False     ResNet18
# 31       128.0        10.0       False     ResNet18
# 32       128.0        10.0        True     ResNet18
# 33       128.0        10.0       False     ResNet18
# 34       128.0        10.0       False     ResNet18
# 35       128.0        10.0        True     ResNet18
# 36       128.0        10.0        True     ResNet18
# 37       128.0        10.0        True     ResNet18
# 38       128.0        10.0       False     ResNet18
# 39       128.0        10.0       False     ResNet18
# 40       128.0        10.0        True     ResNet18
# 41       128.0        10.0       False     ResNet18
# 42       128.0        10.0        True     ResNet18
# 43       128.0        10.0       False     ResNet18
# 44       128.0        10.0        True     ResNet18
# 45       128.0        10.0        True     ResNet18
# 46       128.0        10.0        True     ResNet18
# 47       128.0        10.0       False     ResNet18
# 48       128.0        10.0        True     ResNet18
# 49       128.0        10.0        True     ResNet18
# 50       128.0        10.0        True     ResNet18
# 51       128.0        10.0       False     ResNet18
# 52       128.0        10.0        True     ResNet18
# 53       128.0        10.0        True     ResNet18
# 54       128.0        10.0       False     ResNet18
# 55       128.0        10.0       False     ResNet18
# 56       128.0        10.0       False     ResNet18
# 57       128.0        10.0       False     ResNet18
# 58       128.0        10.0       False     ResNet18
# 59       128.0        10.0        True     ResNet18
# 60       128.0        10.0        True     ResNet18
# 61       128.0        10.0        True     ResNet18
# 62       128.0        10.0        True     ResNet18
# 63       128.0        10.0        True     ResNet18
# 64       128.0        10.0       False     ResNet18
# 65       128.0        10.0       False     ResNet18
# 66       128.0        10.0       False     ResNet18
# 67       128.0        10.0        True     ResNet18
# 68       128.0        10.0        True     ResNet18
# 69       128.0        10.0        True     ResNet18
# 70       128.0        10.0        True     ResNet18
# 71       128.0        10.0        True     ResNet18
# 72       128.0        10.0        True     ResNet18
# 73       128.0        10.0        True     ResNet18
# 74       128.0        10.0       False     ResNet18
# 75       128.0        10.0       False     ResNet18
# 76       128.0        10.0       False     ResNet18
# 77       128.0        10.0       False     ResNet18
# 78       128.0        10.0       False     ResNet18
# 79       128.0        10.0       False     ResNet18
# 80       128.0        10.0       False     ResNet18
# 81       128.0        10.0       False     ResNet18
# 82       128.0        10.0        True     ResNet18
# 83       128.0        10.0        True     ResNet18
# 84       128.0        10.0        True     ResNet18
# 85       128.0        10.0        True     ResNet18
# 86       128.0        10.0        True     ResNet18
# 87       128.0        10.0        True     ResNet18
# 88       128.0        10.0        True     ResNet18
# 89       128.0        10.0        True     ResNet18
# 90       128.0        10.0        True     ResNet18
# 91       128.0        10.0        True     ResNet18
# 92       128.0        10.0       False     ResNet18
# 93       128.0        10.0       False     ResNet18
# 94       128.0        10.0       False     ResNet18
# 95       128.0        10.0       False     ResNet18
# 96       128.0        10.0       False     ResNet18
# 97       128.0        10.0       False     ResNet18
# 98       128.0        10.0       False     ResNet18
# 99       128.0        10.0       False     ResNet18
# 100      128.0        10.0        True     ResNet18
# 101      128.0        10.0        True     ResNet18
# 102      128.0        10.0        True     ResNet18
# 103      128.0        10.0        True     ResNet18
# 104      128.0        10.0        True     ResNet18
# 105      128.0        10.0        True     ResNet18
# 106      128.0        10.0        True     ResNet18
# 107      128.0        10.0        True     ResNet18
# 108      128.0        10.0        True     ResNet18
# 109      128.0        10.0        True     ResNet18
# 110      128.0        10.0       False     ResNet18
# 111      128.0        10.0       False     ResNet18
# 112      128.0        10.0       False     ResNet18
# 113      128.0        10.0       False     ResNet18
# 114      128.0        10.0       False     ResNet18
# 115      128.0        10.0       False     ResNet18
# 116      128.0        10.0       False     ResNet18
# 117      128.0        10.0       False     ResNet18
# 118      128.0        10.0        True     ResNet18
# 119      128.0        10.0        True     ResNet18
# 120      128.0        10.0        True     ResNet18
# 121      128.0        10.0        True     ResNet18
# 122      128.0        10.0        True     ResNet18
# 123      128.0        10.0        True     ResNet18
# 124      128.0        10.0        True     ResNet18
# 125      128.0        10.0        True     ResNet18
# 126      128.0        10.0        True     ResNet18
# 127      128.0        10.0        True     ResNet18
# 128      128.0        10.0        True     ResNet18
# 129      128.0        10.0       False     ResNet18
# 130      128.0        10.0       False     ResNet18
# 131      128.0        10.0       False     ResNet18
# 132      128.0        10.0       False     ResNet18
# 133      128.0        10.0       False     ResNet18
# 134      128.0        10.0       False     ResNet18
# 135      128.0        10.0       False     ResNet18
# 136      128.0        10.0       False     ResNet18
# 137      128.0        10.0        True     ResNet18
# 138      128.0        10.0        True     ResNet18
# 139      128.0        10.0        True     ResNet18
# 140      128.0        10.0        True     ResNet18
# 141      128.0        10.0        True     ResNet18
# 142      128.0        10.0       False     ResNet18
# 143      128.0        10.0       False     ResNet18
# 144      128.0        10.0       False     ResNet18
# 145      128.0        10.0       False     ResNet18
# 146      128.0        10.0       False     ResNet18
# 147      128.0        10.0       False     ResNet18
# 148      128.0        10.0       False     ResNet18
# 149      128.0        10.0       False     ResNet18
# 150      128.0        10.0       False     ResNet18
# 151      128.0        10.0       False     ResNet18
# 152      128.0        10.0       False     ResNet18
# 153      128.0        10.0       False     ResNet18
# 154      128.0        10.0       False     ResNet18
# 155      128.0        10.0        True     ResNet18
# 156      128.0        10.0        True     ResNet18
# 157      128.0        10.0        True     ResNet18
# 158      128.0        10.0        True     ResNet18
# 159      128.0        10.0        True     ResNet18
# 160      128.0        10.0        True     ResNet18
# 161      128.0        10.0        True     ResNet18
# 162      128.0        10.0        True     ResNet18
# 163      128.0        10.0        True     ResNet18
# 164      128.0        10.0        True     ResNet18
# 165      128.0        10.0       False     ResNet18
# 166      128.0        10.0       False     ResNet18
# 167      128.0        10.0       False     ResNet18
# 168      128.0        10.0       False     ResNet18
# 169      128.0        10.0       False     ResNet18
# 170      128.0        10.0       False     ResNet18
# 171      128.0        10.0       False     ResNet18
# 172      128.0        10.0       False     ResNet18
# 173      128.0        10.0       False     ResNet18
# 174      128.0        10.0       False     ResNet18
# 175      128.0        10.0       False     ResNet18
# 176      128.0        10.0       False     ResNet18
# 177      128.0        10.0       False     ResNet18
# 178      128.0        10.0       False     ResNet18
# 179      128.0        10.0       False     ResNet18
# 180      128.0        10.0        True     ResNet18
# 181      128.0        10.0        True     ResNet18
# 182      128.0        10.0        True     ResNet18
# 183      128.0        10.0        True     ResNet18
# 184      128.0        10.0        True     ResNet18
# 185      128.0        10.0        True     ResNet18
# 186      128.0        10.0        True     ResNet18
# 187      128.0        10.0        True     ResNet18
# 188      128.0        10.0        True     ResNet18
# 189      128.0        10.0        True     ResNet18
# 190      128.0        10.0       False     ResNet18
# 191      128.0        10.0       False     ResNet18
# 192      128.0        10.0       False     ResNet18
# 193      128.0        10.0       False     ResNet18
# 194      128.0        10.0       False     ResNet18
# 195        nan         nan       False     ResNet18
# 196        nan         nan       False     ResNet18
# 197        nan         nan       False     ResNet18
# 198        nan         nan       False     ResNet18
# 199        nan         nan       False     ResNet18
# 200        nan         nan       False     ResNet18
# 201        nan         nan       False     ResNet18
# 202        nan         nan       False     ResNet18
# 203        nan         nan       False     ResNet18
# 204        nan         nan       False     ResNet18
# 205        nan         nan        True     ResNet18
# 206        nan         nan        True     ResNet18
# 207        nan         nan        True     ResNet18
# 208        nan         nan        True     ResNet18
# 209        nan         nan        True     ResNet18
# 210        nan         nan        True     ResNet18
# 211        nan         nan        True     ResNet18
# 212        nan         nan        True     ResNet18
# 213        nan         nan        True     ResNet18
# 214        nan         nan        True     ResNet18
# 215        nan         nan        True     ResNet18
# 216        nan         nan        True     ResNet18
# 217        nan         nan        True     ResNet18
# 218        nan         nan        True     ResNet18
# 219        nan         nan        True     ResNet18
# 220        nan         nan        True     ResNet18
# 221        nan         nan        True     ResNet18
# 222        nan         nan        True     ResNet18
# 223        nan         nan        True     ResNet18
# 224        nan         nan        True     ResNet18
# 225        nan         nan       False     ResNet18
# 226        nan         nan       False     ResNet18
# 227        nan         nan       False     ResNet18
# 228        nan         nan       False     ResNet18
# 229        nan         nan       False     ResNet18
# 230        nan         nan       False     ResNet18
# 231        nan         nan       False     ResNet18
# 232        nan         nan       False     ResNet18
# 233        nan         nan       False     ResNet18
# 234        nan         nan       False     ResNet18
# 235        nan         nan       False     ResNet18
# 236        nan         nan       False     ResNet18
# 237        nan         nan       False     ResNet18
# 238        nan         nan        True     ResNet18
# 239        nan         nan        True     ResNet18
# 240        nan         nan        True     ResNet18
# 241        nan         nan        True     ResNet18
# 242        nan         nan        True     ResNet18
# 243        nan         nan        True     ResNet18
#
#                                  classes_list learning_rate classes_per_task  \
# 0    [[4, 9], [5, 6], [2, 7], [3, 8], [0, 1]]         0.003              2.0
# 1    [[1, 3], [0, 8], [6, 7], [4, 9], [2, 5]]         0.003              2.0
# 2    [[2, 3], [1, 8], [4, 9], [5, 7], [0, 6]]         0.003              2.0
# 3    [[1, 2], [3, 6], [7, 8], [0, 9], [4, 5]]         0.003              2.0
# 4    [[0, 7], [4, 5], [8, 9], [2, 6], [1, 3]]         0.003              2.0
# 5    [[3, 7], [0, 9], [1, 8], [2, 4], [5, 6]]         0.003              2.0
# 6    [[6, 7], [2, 9], [5, 8], [3, 4], [0, 1]]         0.003              2.0
# 7    [[3, 7], [0, 4], [6, 9], [1, 5], [2, 8]]         0.003              2.0
# 8    [[6, 7], [2, 5], [4, 9], [3, 8], [0, 1]]         0.003              2.0
# 9    [[3, 9], [1, 2], [0, 7], [5, 8], [4, 6]]         0.003              2.0
# 10   [[0, 2], [6, 9], [5, 7], [3, 8], [1, 4]]         0.003              2.0
# 11   [[5, 7], [2, 9], [3, 4], [6, 8], [0, 1]]         0.003              2.0
# 12   [[3, 5], [2, 8], [7, 9], [0, 6], [1, 4]]         0.003              2.0
# 13   [[4, 8], [5, 6], [7, 9], [0, 1], [2, 3]]         0.003              2.0
# 14   [[4, 5], [2, 9], [6, 7], [1, 3], [0, 8]]         0.003              2.0
# 15   [[0, 5], [1, 3], [8, 9], [2, 7], [4, 6]]         0.003              2.0
# 16   [[1, 7], [0, 2], [5, 6], [3, 8], [4, 9]]         0.003              2.0
# 17   [[1, 4], [3, 9], [6, 8], [5, 7], [0, 2]]         0.003              2.0
# 18   [[0, 6], [1, 5], [4, 9], [3, 7], [2, 8]]         0.003              2.0
# 19   [[1, 6], [7, 9], [5, 8], [3, 4], [0, 2]]         0.003              2.0
# 20   [[5, 7], [4, 8], [0, 9], [1, 3], [2, 6]]         0.003              2.0
# 21   [[0, 5], [4, 8], [3, 7], [1, 2], [6, 9]]         0.003              2.0
# 22   [[1, 2], [7, 8], [5, 6], [0, 9], [3, 4]]         0.003              2.0
# 23   [[0, 5], [3, 7], [1, 9], [2, 6], [4, 8]]         0.003              2.0
# 24   [[1, 5], [6, 7], [0, 2], [3, 8], [4, 9]]         0.003              2.0
# 25   [[3, 4], [0, 8], [5, 7], [2, 6], [1, 9]]         0.003              2.0
# 26   [[1, 3], [4, 9], [2, 6], [5, 8], [0, 7]]         0.003              2.0
# 27   [[0, 6], [1, 4], [3, 5], [2, 7], [8, 9]]         0.003              2.0
# 28   [[1, 5], [3, 8], [0, 4], [2, 7], [6, 9]]         0.003              2.0
# 29   [[1, 5], [0, 9], [2, 8], [6, 7], [3, 4]]         0.003              2.0
# 30   [[1, 3], [8, 9], [2, 5], [4, 6], [0, 7]]         0.003              2.0
# 31   [[5, 6], [3, 9], [0, 7], [1, 8], [2, 4]]         0.003              2.0
# 32   [[1, 5], [3, 7], [4, 9], [0, 8], [2, 6]]         0.003              2.0
# 33   [[5, 6], [4, 8], [7, 9], [0, 3], [1, 2]]         0.003              2.0
# 34   [[3, 6], [2, 7], [0, 5], [1, 8], [4, 9]]         0.003              2.0
# 35   [[2, 7], [0, 9], [1, 5], [6, 8], [3, 4]]         0.003              2.0
# 36   [[0, 5], [7, 9], [4, 8], [1, 3], [2, 6]]         0.003              2.0
# 37   [[3, 5], [8, 9], [2, 6], [1, 4], [0, 7]]         0.003              2.0
# 38   [[2, 8], [0, 9], [4, 5], [3, 7], [1, 6]]         0.003              2.0
# 39   [[2, 9], [3, 4], [0, 8], [5, 6], [1, 7]]         0.003              2.0
# 40   [[1, 9], [2, 3], [6, 7], [4, 8], [0, 5]]         0.003              2.0
# 41   [[6, 8], [2, 5], [0, 4], [3, 9], [1, 7]]         0.003              2.0
# 42   [[5, 8], [0, 7], [2, 4], [3, 9], [1, 6]]         0.003              2.0
# 43   [[3, 6], [1, 7], [4, 5], [0, 9], [2, 8]]         0.003              2.0
# 44   [[5, 7], [3, 6], [4, 8], [0, 1], [2, 9]]         0.003              2.0
# 45   [[6, 9], [4, 8], [0, 3], [1, 2], [5, 7]]         0.003              2.0
# 46   [[1, 2], [8, 9], [3, 4], [0, 6], [5, 7]]         0.003              2.0
# 47   [[4, 6], [0, 9], [1, 3], [2, 7], [5, 8]]         0.003              2.0
# 48   [[3, 6], [2, 7], [1, 9], [0, 8], [4, 5]]         0.003              2.0
# 49   [[1, 7], [0, 4], [2, 5], [3, 9], [6, 8]]         0.003              2.0
# 50   [[2, 5], [0, 7], [1, 6], [8, 9], [3, 4]]         0.003              2.0
# 51   [[1, 6], [0, 8], [7, 9], [2, 5], [3, 4]]         0.003              2.0
# 52   [[0, 9], [2, 6], [3, 5], [4, 7], [1, 8]]         0.003              2.0
# 53   [[3, 7], [4, 5], [0, 6], [8, 9], [1, 2]]         0.003              2.0
# 54   [[6, 8], [3, 9], [2, 4], [0, 5], [1, 7]]         0.003              2.0
# 55   [[1, 8], [4, 9], [0, 3], [2, 5], [6, 7]]         0.003              2.0
# 56   [[2, 4], [1, 9], [0, 6], [7, 8], [3, 5]]         0.003              2.0
# 57   [[1, 6], [3, 4], [2, 5], [0, 7], [8, 9]]         0.003              2.0
# 58   [[1, 7], [0, 3], [2, 4], [8, 9], [5, 6]]         0.003              2.0
# 59   [[4, 6], [1, 5], [3, 7], [2, 8], [0, 9]]         0.003              2.0
# 60   [[1, 9], [2, 5], [0, 3], [4, 6], [7, 8]]         0.003              2.0
# 61   [[4, 5], [3, 8], [1, 6], [7, 9], [0, 2]]         0.003              2.0
# 62   [[2, 8], [6, 9], [4, 5], [1, 7], [0, 3]]         0.003              2.0
# 63   [[5, 9], [4, 7], [0, 1], [3, 8], [2, 6]]         0.003              2.0
# 64   [[2, 7], [6, 8], [1, 9], [0, 5], [3, 4]]         0.003              2.0
# 65   [[4, 6], [8, 9], [1, 5], [2, 7], [0, 3]]         0.003              2.0
# 66   [[0, 9], [6, 8], [1, 7], [3, 4], [2, 5]]         0.003              2.0
# 67   [[3, 5], [8, 9], [2, 6], [0, 1], [4, 7]]         0.003              2.0
# 68   [[5, 8], [7, 9], [2, 3], [0, 6], [1, 4]]         0.003              2.0
# 69   [[6, 4], [3, 1], [8, 5], [0, 9], [7, 2]]         0.003              2.0
# 70   [[8, 1], [7, 4], [3, 2], [9, 0], [6, 5]]         0.003              2.0
# 71   [[0, 3], [8, 2], [1, 5], [7, 4], [6, 9]]         0.003              2.0
# 72   [[1, 4], [8, 0], [9, 6], [7, 3], [5, 2]]         0.003              2.0
# 73   [[9, 6], [7, 1], [2, 8], [5, 4], [0, 3]]         0.003              2.0
# 74   [[5, 3], [6, 2], [1, 8], [0, 4], [9, 7]]         0.003              2.0
# 75   [[7, 6], [9, 1], [3, 4], [8, 5], [0, 2]]         0.003              2.0
# 76   [[8, 7], [3, 9], [0, 6], [2, 5], [1, 4]]         0.003              2.0
# 77   [[8, 7], [9, 4], [3, 1], [2, 0], [5, 6]]         0.003              2.0
# 78   [[1, 2], [0, 5], [7, 8], [4, 9], [3, 6]]         0.003              2.0
# 79   [[6, 1], [7, 9], [5, 4], [3, 2], [8, 0]]         0.003              2.0
# 80   [[5, 2], [1, 3], [7, 4], [8, 9], [6, 0]]         0.003              2.0
# 81   [[2, 1], [7, 9], [4, 8], [0, 6], [3, 5]]         0.003              2.0
# 82   [[2, 6], [4, 8], [0, 5], [7, 9], [1, 3]]         0.003              2.0
# 83   [[6, 2], [9, 7], [8, 3], [5, 4], [0, 1]]         0.003              2.0
# 84   [[2, 0], [6, 8], [4, 5], [1, 3], [9, 7]]         0.003              2.0
# 85   [[7, 0], [3, 4], [8, 6], [9, 2], [5, 1]]         0.003              2.0
# 86   [[8, 1], [3, 7], [2, 6], [0, 5], [9, 4]]         0.003              2.0
# 87   [[2, 4], [3, 0], [1, 5], [7, 6], [9, 8]]         0.003              2.0
# 88   [[6, 1], [7, 3], [8, 5], [2, 4], [0, 9]]         0.003              2.0
# 89   [[0, 1], [8, 4], [7, 3], [5, 2], [9, 6]]         0.003              2.0
# 90   [[2, 5], [8, 1], [6, 0], [3, 9], [4, 7]]         0.003              2.0
# 91   [[3, 8], [6, 0], [7, 9], [4, 5], [1, 2]]         0.003              2.0
# 92   [[6, 8], [5, 4], [0, 3], [1, 2], [9, 7]]         0.003              2.0
# 93   [[4, 0], [3, 6], [5, 8], [9, 2], [1, 7]]         0.003              2.0
# 94   [[6, 0], [3, 7], [5, 1], [8, 2], [4, 9]]         0.003              2.0
# 95   [[8, 0], [9, 7], [3, 1], [2, 6], [4, 5]]         0.003              2.0
# 96   [[3, 1], [6, 0], [9, 8], [5, 7], [2, 4]]         0.003              2.0
# 97   [[7, 4], [0, 6], [1, 2], [8, 3], [9, 5]]         0.003              2.0
# 98   [[4, 7], [6, 8], [2, 1], [5, 3], [9, 0]]         0.003              2.0
# 99   [[1, 4], [2, 0], [8, 5], [9, 7], [3, 6]]         0.003              2.0
# 100  [[8, 3], [4, 5], [2, 7], [1, 6], [9, 0]]         0.003              2.0
# 101  [[1, 5], [9, 8], [7, 6], [4, 0], [2, 3]]         0.003              2.0
# 102  [[1, 9], [5, 2], [4, 6], [3, 8], [0, 7]]         0.003              2.0
# 103  [[5, 3], [6, 1], [0, 4], [2, 8], [7, 9]]         0.003              2.0
# 104  [[5, 0], [6, 4], [2, 9], [1, 3], [8, 7]]         0.003              2.0
# 105  [[2, 6], [1, 9], [4, 5], [7, 8], [0, 3]]         0.003              2.0
# 106  [[3, 5], [8, 1], [0, 7], [6, 9], [2, 4]]         0.003              2.0
# 107  [[7, 5], [3, 0], [1, 9], [6, 4], [8, 2]]         0.003              2.0
# 108  [[3, 7], [4, 8], [9, 2], [0, 5], [1, 6]]         0.003              2.0
# 109  [[2, 1], [7, 8], [0, 9], [3, 6], [5, 4]]         0.003              2.0
# 110  [[5, 6], [3, 2], [9, 7], [0, 4], [8, 1]]         0.003              2.0
# 111  [[9, 6], [7, 2], [4, 0], [1, 3], [8, 5]]         0.003              2.0
# 112  [[6, 9], [2, 8], [0, 1], [7, 3], [5, 4]]         0.003              2.0
# 113  [[3, 2], [7, 6], [8, 5], [0, 1], [4, 9]]         0.003              2.0
# 114  [[0, 1], [5, 4], [9, 2], [7, 6], [8, 3]]         0.003              2.0
# 115  [[5, 8], [1, 4], [9, 3], [2, 7], [0, 6]]         0.003              2.0
# 116  [[5, 2], [0, 1], [8, 7], [3, 9], [4, 6]]         0.003              2.0
# 117  [[2, 6], [0, 4], [1, 9], [7, 8], [3, 5]]         0.003              2.0
# 118  [[9, 8], [0, 1], [2, 3], [4, 7], [5, 6]]         0.003              2.0
# 119  [[6, 5], [9, 0], [4, 3], [7, 2], [8, 1]]         0.003              2.0
# 120  [[7, 9], [8, 1], [3, 0], [6, 2], [4, 5]]         0.003              2.0
# 121  [[4, 6], [3, 2], [1, 0], [7, 8], [5, 9]]         0.003              2.0
# 122  [[0, 5], [6, 3], [9, 8], [7, 4], [2, 1]]         0.003              2.0
# 123  [[2, 6], [8, 7], [0, 5], [1, 3], [9, 4]]         0.003              2.0
# 124  [[2, 9], [0, 8], [1, 5], [7, 3], [4, 6]]         0.003              2.0
# 125  [[5, 0], [1, 7], [8, 9], [6, 3], [4, 2]]         0.003              2.0
# 126  [[1, 3], [2, 9], [6, 4], [0, 7], [5, 8]]         0.003              2.0
# 127  [[1, 0], [3, 2], [4, 6], [7, 5], [8, 9]]         0.003              2.0
# 128  [[6, 0], [8, 9], [7, 5], [3, 2], [4, 1]]         0.003              2.0
# 129  [[2, 5], [0, 4], [8, 9], [3, 7], [6, 1]]         0.003              2.0
# 130  [[0, 7], [2, 1], [5, 8], [6, 3], [4, 9]]         0.003              2.0
# 131  [[1, 4], [2, 8], [9, 3], [0, 7], [5, 6]]         0.003              2.0
# 132  [[3, 7], [2, 8], [0, 6], [4, 5], [9, 1]]         0.003              2.0
# 133  [[3, 0], [8, 1], [6, 9], [5, 2], [7, 4]]         0.003              2.0
# 134  [[3, 4], [5, 1], [7, 0], [8, 9], [6, 2]]         0.003              2.0
# 135  [[2, 3], [5, 4], [1, 0], [7, 9], [8, 6]]         0.003              2.0
# 136  [[7, 0], [5, 4], [9, 2], [3, 6], [1, 8]]         0.003              2.0
# 137  [[1, 5], [8, 4], [6, 7], [3, 9], [2, 0]]         0.003              2.0
# 138  [[1, 8], [4, 2], [0, 5], [9, 6], [3, 7]]         0.003              2.0
# 139  [[6, 3], [2, 0], [9, 5], [4, 7], [8, 1]]         0.003              2.0
# 140  [[1, 7], [3, 0], [5, 2], [6, 4], [8, 9]]         0.003              2.0
# 141  [[9, 6], [7, 1], [0, 4], [8, 5], [2, 3]]         0.003              2.0
# 142  [[0, 7], [2, 4], [8, 3], [6, 9], [5, 1]]         0.003              2.0
# 143  [[5, 3], [6, 4], [0, 8], [7, 1], [9, 2]]         0.003              2.0
# 144  [[0, 1], [5, 6], [4, 8], [3, 7], [9, 2]]         0.003              2.0
# 145  [[1, 8], [9, 3], [4, 7], [0, 6], [5, 2]]         0.003              2.0
# 146  [[5, 3], [8, 4], [9, 6], [1, 7], [2, 0]]         0.003              2.0
# 147  [[4, 6], [7, 5], [2, 0], [1, 8], [3, 9]]         0.003              2.0
# 148  [[5, 2], [3, 9], [6, 8], [0, 1], [4, 7]]         0.003              2.0
# 149  [[8, 0], [5, 2], [6, 3], [7, 4], [9, 1]]         0.003              2.0
# 150  [[3, 7], [8, 2], [5, 9], [0, 6], [1, 4]]         0.003              2.0
# 151  [[2, 5], [7, 0], [6, 4], [3, 9], [8, 1]]         0.003              2.0
# 152  [[0, 9], [3, 5], [2, 1], [6, 7], [4, 8]]         0.003              2.0
# 153  [[2, 8], [9, 0], [3, 5], [6, 7], [4, 1]]         0.003              2.0
# 154  [[0, 6], [5, 1], [8, 7], [4, 2], [3, 9]]         0.003              2.0
# 155  [[5, 4], [1, 6], [3, 0], [8, 9], [2, 7]]         0.003              2.0
# 156  [[0, 8], [6, 3], [5, 1], [7, 9], [4, 2]]         0.003              2.0
# 157  [[8, 0], [3, 4], [9, 2], [6, 1], [5, 7]]         0.003              2.0
# 158  [[5, 6], [3, 8], [9, 0], [2, 4], [7, 1]]         0.003              2.0
# 159  [[1, 0], [6, 7], [3, 2], [9, 8], [5, 4]]         0.003              2.0
# 160  [[6, 0], [7, 8], [9, 2], [4, 1], [3, 5]]         0.003              2.0
# 161  [[0, 9], [1, 7], [3, 8], [5, 4], [2, 6]]         0.003              2.0
# 162  [[5, 4], [9, 0], [1, 8], [2, 7], [3, 6]]         0.003              2.0
# 163  [[8, 7], [0, 6], [3, 9], [1, 5], [2, 4]]         0.003              2.0
# 164  [[6, 4], [8, 5], [1, 2], [7, 0], [9, 3]]         0.003              2.0
# 165  [[0, 2], [8, 5], [4, 6], [1, 9], [3, 7]]         0.003              2.0
# 166  [[4, 6], [8, 2], [3, 9], [1, 5], [7, 0]]         0.003              2.0
# 167  [[6, 1], [0, 3], [7, 2], [8, 4], [5, 9]]         0.003              2.0
# 168  [[9, 3], [4, 7], [8, 0], [2, 1], [6, 5]]         0.003              2.0
# 169  [[4, 6], [0, 5], [7, 8], [2, 9], [3, 1]]         0.003              2.0
# 170  [[6, 8], [0, 5], [4, 7], [3, 9], [1, 2]]         0.003              2.0
# 171  [[1, 3], [4, 7], [5, 8], [6, 9], [2, 0]]         0.003              2.0
# 172  [[3, 0], [2, 5], [7, 6], [4, 1], [8, 9]]         0.003              2.0
# 173  [[4, 5], [8, 3], [9, 2], [7, 1], [6, 0]]         0.003              2.0
# 174  [[6, 9], [1, 2], [0, 8], [7, 3], [4, 5]]         0.003              2.0
# 175  [[2, 9], [3, 6], [1, 0], [4, 8], [7, 5]]         0.003              2.0
# 176  [[8, 4], [3, 6], [0, 7], [9, 1], [2, 5]]         0.003              2.0
# 177  [[4, 8], [5, 1], [3, 6], [0, 2], [9, 7]]         0.003              2.0
# 178  [[8, 6], [1, 2], [5, 4], [0, 7], [9, 3]]         0.003              2.0
# 179  [[8, 1], [9, 7], [5, 6], [4, 3], [0, 2]]         0.003              2.0
# 180  [[0, 6], [9, 1], [7, 8], [2, 4], [3, 5]]         0.003              2.0
# 181  [[1, 8], [0, 9], [3, 7], [2, 4], [5, 6]]         0.003              2.0
# 182  [[3, 7], [8, 0], [6, 1], [4, 5], [9, 2]]         0.003              2.0
# 183  [[9, 8], [0, 1], [5, 2], [7, 4], [6, 3]]         0.003              2.0
# 184  [[4, 5], [0, 7], [9, 1], [2, 6], [8, 3]]         0.003              2.0
# ...
# 118      dead_leaves-squares                nan                  128
# 119      dead_leaves-squares                nan                  128
# 120      dead_leaves-squares                nan                  128
# 121      dead_leaves-squares                nan                  128
# 122      dead_leaves-squares                nan                  128
# 123      dead_leaves-squares                nan                  128
# 124     dead_leaves-oriented                nan                  128
# 125     dead_leaves-oriented                nan                  128
# 126     dead_leaves-oriented                nan                  128
# 127     dead_leaves-oriented                nan                  128
# 128     dead_leaves-oriented                nan                  128
# 129     dead_leaves-oriented                nan                  128
# 130     dead_leaves-oriented                nan                  128
# 131     dead_leaves-oriented                nan                  128
# 132     dead_leaves-oriented                nan                  128
# 133        dead_leaves-mixed                nan                  128
# 134        dead_leaves-mixed                nan                  128
# 135        dead_leaves-mixed                nan                  128
# 136        dead_leaves-mixed                nan                  128
# 137        dead_leaves-mixed                nan                  128
# 138        dead_leaves-mixed                nan                  128
# 139        dead_leaves-mixed                nan                  128
# 140        dead_leaves-mixed                nan                  128
# 141        dead_leaves-mixed                nan                  128
# 142          stylegan-random                nan                  128
# 143        stylegan-highfreq                nan                  128
# 144      stat-spectrum_color                nan                  128
# 145            stat-spectrum                nan                  128
# 146     dead_leaves-textures                nan                  128
# 147      dead_leaves-squares                nan                  128
# 148     dead_leaves-oriented                nan                  128
# 149        dead_leaves-mixed                nan                  128
# 150  stat-spectrum_color_wmm                nan                  128
# 151  stat-spectrum_color_wmm                nan                  128
# 152  stat-spectrum_color_wmm                nan                  128
# 153  stat-spectrum_color_wmm                nan                  128
# 154  stat-spectrum_color_wmm                nan                  128
# 155  stat-spectrum_color_wmm                nan                  128
# 156  stat-spectrum_color_wmm                nan                  128
# 157  stat-spectrum_color_wmm                nan                  128
# 158  stat-spectrum_color_wmm                nan                  128
# 159  stat-spectrum_color_wmm                nan                  128
# 160                 stat-wmm                nan                  128
# 161                 stat-wmm                nan                  128
# 162                 stat-wmm                nan                  128
# 163                 stat-wmm                nan                  128
# 164                 stat-wmm                nan                  128
# 165                 stat-wmm                nan                  128
# 166                 stat-wmm                nan                  128
# 167                 stat-wmm                nan                  128
# 168                 stat-wmm                nan                  128
# 169                 stat-wmm                nan                  128
# 170                 stat-wmm                nan                  128
# 171                 stat-wmm                nan                  128
# 172                 stat-wmm                nan                  128
# 173                 stat-wmm                nan                  128
# 174                 stat-wmm                nan                  128
# 175  stat-spectrum_color_wmm                nan                  128
# 176  stat-spectrum_color_wmm                nan                  128
# 177  stat-spectrum_color_wmm                nan                  128
# 178  stat-spectrum_color_wmm                nan                  128
# 179  stat-spectrum_color_wmm                nan                  128
# 180  stat-spectrum_color_wmm                nan                  128
# 181  stat-spectrum_color_wmm                nan                  128
# 182  stat-spectrum_color_wmm                nan                  128
# 183  stat-spectrum_color_wmm                nan                  128
# 184  stat-spectrum_color_wmm                nan                  128
# 185                 stat-wmm                nan                  128
# 186                 stat-wmm                nan                  128
# 187                 stat-wmm                nan                  128
# 188                 stat-wmm                nan                  128
# 189                 stat-wmm                nan                  128
# 190                                         nan                  128
# 191                                         nan                  128
# 192                                         nan                  128
# 193                                         nan                  128
# 194                                         nan                  128
# 195                 stat-wmm                nan                  128
# 196                 stat-wmm                nan                  128
# 197                 stat-wmm                nan                  128
# 198                 stat-wmm                nan                  128
# 199                 stat-wmm                nan                  128
# 200  stat-spectrum_color_wmm                nan                  128
# 201  stat-spectrum_color_wmm                nan                  128
# 202  stat-spectrum_color_wmm                nan                  128
# 203  stat-spectrum_color_wmm                nan                  128
# 204  stat-spectrum_color_wmm                nan                  128
# 205  stat-spectrum_color_wmm                nan                  128
# 206  stat-spectrum_color_wmm                nan                  128
# 207  stat-spectrum_color_wmm                nan                  128
# 208  stat-spectrum_color_wmm                nan                  128
# 209  stat-spectrum_color_wmm                nan                  128
# 210  stat-spectrum_color_wmm                nan                  128
# 211  stat-spectrum_color_wmm                nan                  128
# 212  stat-spectrum_color_wmm                nan                  128
# 213  stat-spectrum_color_wmm                nan                  128
# 214  stat-spectrum_color_wmm                nan                  128
# 215  stat-spectrum_color_wmm                nan                  128
# 216  stat-spectrum_color_wmm                nan                  128
# 217  stat-spectrum_color_wmm                nan                  128
# 218  stat-spectrum_color_wmm                nan                  128
# 219  stat-spectrum_color_wmm                nan                  128
# 220  stat-spectrum_color_wmm                nan                  128
# 221  stat-spectrum_color_wmm                nan                  128
# 222  stat-spectrum_color_wmm                nan                  128
# 223  stat-spectrum_color_wmm                nan                  128
# 224  stat-spectrum_color_wmm                nan                  128
# 225                     None                nan                  128
# 226                     None                nan                  128
# 227                     None                nan                  128
# 228                     None                nan                  128
# 229                     None                nan                  128
# 230                     None                nan                  128
# 231                     None                nan                  128
# 232                     None                nan                  128
# 233                     None                nan                  128
# 234                     None                nan                  128
# 235                     None                nan                  128
# 236                     None                nan                  128
# 237                 stat-wmm                nan                  128
# 238                 stat-wmm                nan                  128
# 239                 stat-wmm                nan                  128
# 240                 stat-wmm                nan                  128
# 241                 stat-wmm                nan                  128
# 242                 stat-wmm                nan                  128
# 243                 stat-wmm                nan                  128
#
#     separate_noise_output
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# 5                     nan
# 6                     nan
# 7                     nan
# 8                     nan
# 9                     nan
# 10                    nan
# 11                    nan
# 12                    nan
# 13                    nan
# 14                    nan
# 15                    nan
# 16                    nan
# 17                    nan
# 18                    nan
# 19                    nan
# 20                    nan
# 21                    nan
# 22                    nan
# 23                    nan
# 24                    nan
# 25                    nan
# 26                    nan
# 27                    nan
# 28                    nan
# 29                    nan
# 30                    nan
# 31                    nan
# 32                    nan
# 33                    nan
# 34                    nan
# 35                    nan
# 36                    nan
# 37                    nan
# 38                    nan
# 39                    nan
# 40                    nan
# 41                    nan
# 42                    nan
# 43                    nan
# 44                    nan
# 45                    nan
# 46                    nan
# 47                    nan
# 48                    nan
# 49                    nan
# 50                    nan
# 51                    nan
# 52                    nan
# 53                    nan
# 54                    nan
# 55                    nan
# 56                    nan
# 57                    nan
# 58                    nan
# 59                    nan
# 60                    nan
# 61                    nan
# 62                    nan
# 63                    nan
# 64                    nan
# 65                    nan
# 66                    nan
# 67                    nan
# 68                    nan
# 69                    nan
# 70                    nan
# 71                    nan
# 72                    nan
# 73                    nan
# 74                    nan
# 75                    nan
# 76                    nan
# 77                    nan
# 78                    nan
# 79                    nan
# 80                    nan
# 81                    nan
# 82                    nan
# 83                    nan
# 84                    nan
# 85                    nan
# 86                    nan
# 87                    nan
# 88                    nan
# 89                    nan
# 90                    nan
# 91                    nan
# 92                    nan
# 93                    nan
# 94                    nan
# 95                    nan
# 96                    nan
# 97                    nan
# 98                    nan
# 99                    nan
# 100                   nan
# 101                   nan
# 102                   nan
# 103                   nan
# 104                   nan
# 105                   nan
# 106                   nan
# 107                   nan
# 108                   nan
# 109                   nan
# 110                   nan
# 111                   nan
# 112                   nan
# 113                   nan
# 114                   nan
# 115                   nan
# 116                   nan
# 117                   nan
# 118                   nan
# 119                   nan
# 120                   nan
# 121                   nan
# 122                   nan
# 123                   nan
# 124                   nan
# 125                   nan
# 126                   nan
# 127                   nan
# 128                   nan
# 129                   nan
# 130                   nan
# 131                   nan
# 132                   nan
# 133                   nan
# 134                   nan
# 135                   nan
# 136                   nan
# 137                   nan
# 138                   nan
# 139                   nan
# 140                   nan
# 141                   nan
# 142                   nan
# 143                   nan
# 144                   nan
# 145                   nan
# 146                   nan
# 147                   nan
# 148                   nan
# 149                   nan
# 150                   nan
# 151                   nan
# 152                   nan
# 153                   nan
# 154                   nan
# 155                   nan
# 156                   nan
# 157                   nan
# 158                   nan
# 159                   nan
# 160                   nan
# 161                   nan
# 162                   nan
# 163                   nan
# 164                   nan
# 165                   nan
# 166                   nan
# 167                   nan
# 168                   nan
# 169                   nan
# 170                   nan
# 171                   nan
# 172                   nan
# 173                   nan
# 174                   nan
# 175                   nan
# 176                   nan
# 177                   nan
# 178                   nan
# 179                   nan
# 180                   nan
# 181                   nan
# 182                   nan
# 183                   nan
# 184                   nan
# 185                   nan
# 186                   nan
# 187                   nan
# 188                   nan
# 189                   nan
# 190                   nan
# 191                   nan
# 192                   nan
# 193                   nan
# 194                   nan
# 195                   nan
# 196                   nan
# 197                   nan
# 198                   nan
# 199                   nan
# 200                   nan
# 201                   nan
# 202                   nan
# 203                   nan
# 204                   nan
# 205                   nan
# 206                   nan
# 207                   nan
# 208                   nan
# 209                   nan
# 210                   nan
# 211                   nan
# 212                   nan
# 213                   nan
# 214                   nan
# 215                   nan
# 216                   nan
# 217                   nan
# 218                   nan
# 219                   nan
# 220                   nan
# 221                   nan
# 222                   nan
# 223                   nan
# 224                   nan
# 225                   nan
# 226                   nan
# 227                   nan
# 228                   nan
# 229                   nan
# 230                   nan
# 231                   nan
# 232                   nan
# 233                   nan
# 234                   nan
# 235                   nan
# 236                   nan
# 237                   nan
# 238                   nan
# 239                   nan
# 240                   nan
# 241                   nan
# 242                   nan
# 243                   nan

# %%
setup_columns = ['project',
'setup',
'learning_rate',
'architecture',
'dataset',
'rehearsal_dataset',
'epochs',
'batch_size_rehearsal',
'batch_size',
'pretraining',
'num_classes',
'classes_per_task',
'optimizer']

# %%
df_to_run = df_to_run[df_to_run['epochs'] == '5']

# %%
df_to_run = df_to_run[setup_columns].drop_duplicates().sort_values(by=['rehearsal_dataset'])

# %%
df_to_run
# Out:
#                              project   setup learning_rate architecture  \
# 7    rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 31   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 35   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 129  rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 40   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 45   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 30   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 53   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 34   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 49   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 51   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 61   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 54   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 16   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 13   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 14   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 0    rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 59   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 64   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 65   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
# 67   rehersal ResNet CIFAR10 Task IL  taskIL         0.003     ResNet18
#
#      dataset        rehearsal_dataset epochs batch_size_rehearsal batch_size  \
# 7    CIFAR10                               5                  128        128
# 31   CIFAR10        dead_leaves-mixed      5                  128        128
# 35   CIFAR10        dead_leaves-mixed      5                  128        128
# 129  CIFAR10     dead_leaves-oriented      5                  128        128
# 40   CIFAR10     dead_leaves-oriented      5                  128        128
# 45   CIFAR10      dead_leaves-squares      5                  128        128
# 30   CIFAR10      dead_leaves-squares      5                  128        128
# 53   CIFAR10     dead_leaves-textures      5                  128        128
# 34   CIFAR10     dead_leaves-textures      5                  128        128
# 49   CIFAR10            stat-spectrum      5                  128        128
# 51   CIFAR10            stat-spectrum      5                  128        128
# 61   CIFAR10      stat-spectrum_color      5                  128        128
# 54   CIFAR10      stat-spectrum_color      5                  128        128
# 16   CIFAR10  stat-spectrum_color_wmm      5                  128        128
# 13   CIFAR10  stat-spectrum_color_wmm      5                  128        128
# 14   CIFAR10                 stat-wmm      5                  128        128
# 0    CIFAR10                 stat-wmm      5                  128        128
# 59   CIFAR10        stylegan-highfreq      5                  128        128
# 64   CIFAR10        stylegan-highfreq      5                  128        128
# 65   CIFAR10          stylegan-random      5                  128        128
# 67   CIFAR10          stylegan-random      5                  128        128
#
#     pretraining num_classes classes_per_task optimizer
# 7         False          10                2       SGD
# 31        False          10                2       SGD
# 35         True          10                2       SGD
# 129       False          10                2       SGD
# 40         True          10                2       SGD
# 45         True          10                2       SGD
# 30        False          10                2       SGD
# 53         True          10                2       SGD
# 34        False          10                2       SGD
# 49         True          10                2       SGD
# 51        False          10                2       SGD
# 61         True          10                2       SGD
# 54        False          10                2       SGD
# 16         True          10                2       SGD
# 13        False          10                2       SGD
# 14         True          10                2      None
# 0         False          10                2       SGD
# 59         True          10                2       SGD
# 64        False          10                2       SGD
# 65        False          10                2       SGD
# 67         True          10                2       SGD

# %%
len(df_to_run)
# Out:
# 21

# %%
# df_to_run = df.copy()

# df_to_run.loc[:,['batch_size', 'batch_size_rehearsal', 'num_classes', 'classes_per_task']] = df_to_run.loc[:,['batch_size', 'batch_size_rehearsal', 'num_classes', 'classes_per_task']].astype(float).astype(int)

# %%
n_times = 5

run_params = []
for i in range(len(df_to_run)):
    for n in range(n_times):
        execution_params = ""
        for setup_column in setup_columns:
            execution_params += setup_column+'="'+str(df_to_run.iloc[i][setup_column])+'"'+" "
        run_params.append(execution_params)

# %%
len(run_params)
# Out:
# 105

# %%
# f = open(f'{project}.pickle',"wb")
# pickle.dump(run_params ,f)
# f.close()

# %%
# project = 'rehersal ResNet CIFAR10 Task IL'
# run_params = pickle.load(open(f'{project}.pickle', "rb"))

# %%
i = 0
for run_param in run_params:
    print("/net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py "+run_param+"&"+"\n")
    i+=1
    if i%5 == 0:
        print("--------------------")
# Out:
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-mixed" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-mixed" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-mixed" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-mixed" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-mixed" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-mixed" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-mixed" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-mixed" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-mixed" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-mixed" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-oriented" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-oriented" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-oriented" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-oriented" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-oriented" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-oriented" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-oriented" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-oriented" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-oriented" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-oriented" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-squares" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-squares" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-squares" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-squares" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-squares" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-squares" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-squares" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-squares" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-squares" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-squares" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-textures" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-textures" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-textures" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-textures" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-textures" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-textures" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-textures" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-textures" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-textures" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="dead_leaves-textures" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color_wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color_wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color_wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color_wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color_wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color_wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color_wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color_wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color_wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-spectrum_color_wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="None" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="None" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="None" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="None" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="None" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stat-wmm" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-highfreq" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-highfreq" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-highfreq" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-highfreq" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-highfreq" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-highfreq" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-highfreq" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-highfreq" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-highfreq" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-highfreq" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-random" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-random" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-random" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-random" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-random" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="False" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-random" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-random" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-random" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-random" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# /net/tscratch/people/plgjsobolewski/conda_env/bin/python run_experiment.py project="rehersal ResNet CIFAR10 Task IL" setup="taskIL" learning_rate="0.003" architecture="ResNet18" dataset="CIFAR10" rehearsal_dataset="stylegan-random" epochs="5" batch_size_rehearsal="128" batch_size="128" pretraining="True" num_classes="10" classes_per_task="2" optimizer="SGD" &
#
# --------------------
