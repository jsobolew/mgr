# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("wandb_export_2023-11-18T18_53_30.437+01_00.csv")

# %%
df[df['rehearsal_dataset']=='stat-wmm']
# Out:
#                      Name     State Notes            User  Tags  \
# 5       polished-moon-174    failed     -  qba-sobolewski   NaN
# 6      elated-feather-173    failed     -  qba-sobolewski   NaN
# 7       confused-frog-172    failed     -  qba-sobolewski   NaN
# 8     stilted-silence-171    failed     -  qba-sobolewski   NaN
# 9    chocolate-durian-170    failed     -  qba-sobolewski   NaN
# ..                    ...       ...   ...             ...   ...
# 109        dulcet-pond-42  finished     -  qba-sobolewski   NaN
# 110  bumbling-universe-41  finished     -  qba-sobolewski   NaN
# 111    graceful-monkey-40  finished     -  qba-sobolewski   NaN
# 112   driven-microwave-39  finished     -  qba-sobolewski   NaN
# 113       sweet-meadow-38  finished     -  qba-sobolewski   NaN
#
#                       Created  Runtime  Sweep         architecture  \
# 5    2023-11-12T14:15:16.000Z        9    NaN         SmallAlexNet
# ...
