# %%
import os
os.chdir("../")

import pickle

from visualization import Visualization

# %% [markdown]
# # ResNet18

# %%
project = 'rehersal ResNet CIFAR10 Task IL'


viz_resnet18 = Visualization(project=project,UID=['rehearsal_dataset', 'batch_size_rehearsal', 'pretraining', 'learning_rate', 'epochs', 'separate_noise_output'], y_min=30)

# %%
with open('ResNet18/run_names_with_true.pkl', 'rb') as file:
    run_names_with_true = pickle.load(file)

viz_resnet18.df.loc[viz_resnet18.df.run_name.isin(run_names_with_true), 'separate_noise_output'] = 'True'

# %%
viz_resnet18.df.separate_noise_output[viz_resnet18.df.separate_noise_output!='True'] = 'False'

# %%
viz_resnet18.df.separate_noise_output.value_counts()
# Out:
# False    607
# True     219
# Name: separate_noise_output, dtype: int64

# %%
idxs = viz_resnet18.df[viz_resnet18.df['UID']=='stat-wmm;128;False;0.003;5;nan;'].index.values[:5]
idxs
# Out:
# array([184, 185, 186, 189, 190], dtype=int64)

# %%
viz_resnet18.plot_single_setting_aggregated('stat-wmm;128;False;0.003;5;nan', fontsize=25, filename="model_resnet18", layout='vertical', unixe_idxs=list(idxs))
# Out:
# c:\Users\QbaSo\PycharmProjects\mgr\myCode\Results visualization\visualization.py:405: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(metrics_df.to_latex(index=False))
# \begin{tabular}{rrrrl}
# \toprule
#  task &  acc at the end &  mean acc &  acc loss per task & split \\
# \midrule
#     0 &           76.59 &     76.16 &               1.50 &  test \\
#     1 &           73.08 &     74.34 &               2.09 &  test \\
#     2 &           73.90 &     74.40 &               3.04 &  test \\
#     3 &           81.95 &     79.94 &               2.99 &  test \\
#     4 &           87.86 &     81.77 &               0.00 &  test \\
# \bottomrule
# \end{tabular}

# %%
idxs = viz_resnet18.df[viz_resnet18.df['UID']==';128;False;0.003;5;nan;'].index.values[:5]
idxs
# Out:
# array([252, 253, 254, 255, 256], dtype=int64)

# %%
viz_resnet18.plot_single_setting_aggregated(';128;False;0.003;5;nan', fontsize=25, filename="model_resnet18", layout='vertical', unixe_idxs=list(idxs))
# Out:
# c:\Users\QbaSo\PycharmProjects\mgr\myCode\Results visualization\visualization.py:405: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(metrics_df.to_latex(index=False))
# \begin{tabular}{rrrrl}
# \toprule
#  task &  acc at the end &  mean acc &  acc loss per task & split \\
# \midrule
#     0 &           72.93 &     75.85 &               2.31 &  test \\
#     1 &           74.03 &     74.17 &               2.23 &  test \\
#     2 &           78.08 &     80.63 &               3.80 &  test \\
#     3 &           86.47 &     84.68 &               2.42 &  test \\
#     4 &           89.98 &     82.76 &               0.00 &  test \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # ResNet34

# %%
project = 'rehersal ResNet34 CIFAR10 Task IL'


viz_resnet34 = Visualization(project=project,UID=['rehearsal_dataset', 'batch_size_rehearsal', 'pretraining', 'learning_rate', 'epochs', 'separate_noise_output'], y_min=30)

# %%
viz_resnet34.df.UID.value_counts()
# Out:
# ;128;False;0.01;5;False;             11
# stat-wmm;128;False;0.003;5;False;    10
# stat-wmm;128;True;0.003;5;False;     10
# ;128;False;0.003;5;False;            10
# stat-wmm;128;True;0.01;5;False;      10
# stat-wmm;128;False;0.01;5;False;     10
# ;128;False;0.0003;5;False;            1
# ;128;False;1e-05;5;False;             1
# ;128;False;0.0001;5;False;            1
# ;128;False;0.03;5;False;              1
# ;128;False;0.001;5;False;             1
# ;128;False;3e-05;5;False;             1
# Name: UID, dtype: int64

# %%
idxs = viz_resnet34.df[viz_resnet34.df['UID']=='stat-wmm;128;False;0.003;5;False;'].index.values[:5]
idxs
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
viz_resnet34.plot_single_setting_aggregated('stat-wmm;128;False;0.003;5;False', fontsize=25, filename="model_resnet34", layout='vertical', unixe_idxs=list(idxs))
# Out:
# c:\Users\QbaSo\PycharmProjects\mgr\myCode\Results visualization\visualization.py:405: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(metrics_df.to_latex(index=False))
# \begin{tabular}{rrrrl}
# \toprule
#  task &  acc at the end &  mean acc &  acc loss per task & split \\
# \midrule
#     0 &           68.78 &     69.12 &               2.28 &  test \\
#     1 &           70.18 &     71.71 &               2.31 &  test \\
#     2 &           65.03 &     66.16 &               3.24 &  test \\
#     3 &           75.14 &     75.21 &               4.48 &  test \\
#     4 &           81.03 &     77.13 &               0.00 &  test \\
# \bottomrule
# \end{tabular}

# %%
idxs = viz_resnet34.df[viz_resnet34.df['UID']==';128;False;0.003;5;False;'].index.values[:5]
idxs
# Out:
# array([20, 21, 22, 23, 24], dtype=int64)

# %%
viz_resnet34.plot_single_setting_aggregated(';128;False;0.003;5;False', fontsize=25, filename="model_resnet34", layout='vertical', unixe_idxs=list(idxs))
# Out:
# c:\Users\QbaSo\PycharmProjects\mgr\myCode\Results visualization\visualization.py:405: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(metrics_df.to_latex(index=False))
# \begin{tabular}{rrrrl}
# \toprule
#  task &  acc at the end &  mean acc &  acc loss per task & split \\
# \midrule
#     0 &           75.34 &     79.22 &               2.81 &  test \\
#     1 &           77.81 &     82.00 &               3.41 &  test \\
#     2 &           80.00 &     84.01 &               4.84 &  test \\
#     3 &           79.28 &     81.50 &               7.54 &  test \\
#     4 &           83.32 &     79.50 &               0.00 &  test \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # AlexNet

# %%
project = 'rehersal Alexnet MNIST Task IL tr-t split v2'


viz_alexnet = Visualization(project=project,UID=['rehearsal_dataset', 'batch_size_rehearsal', 'pretraining', 'learning_rate', 'epochs'], y_min=30)

# %%
viz_alexnet.df.UID.value_counts()
# Out:
# ;128.0;False;0.001;20;                          17
# stat-wmm;64.0;nan;0.01;5;                       17
# dead_leaves-squares;128.0;False;0.001;5;        14
# stylegan-highfreq;128.0;False;0.001;5;           9
# dead_leaves-textures;128.0;True;0.001;5;         9
# dead_leaves-oriented;128.0;True;0.001;5;         9
# stat-spectrum_color_wmm;128.0;True;0.001;5;      8
# dead_leaves-mixed;128.0;True;0.001;5;            7
# stat-spectrum;128.0;False;0.001;5;               7
# stat-wmm;128.0;True;0.001;20;                    7
# stat-spectrum_color_wmm;128.0;True;0.001;20;     7
# stat-spectrum_color;128.0;False;0.001;5;         7
# stylegan-random;128.0;False;0.001;5;             7
# stylegan-random;128.0;True;0.001;5;              7
# stat-wmm;128.0;False;0.001;5;                    6
# dead_leaves-squares;nan;nan;0.01;5;              6
# stat-wmm;128.0;True;0.001;5;                     6
# stylegan-highfreq;128.0;True;0.001;5;            6
# ...

# %%
idxs = viz_alexnet.df[viz_alexnet.df['UID']=='stat-wmm;128.0;False;0.001;5;'].index.values[:5]

# %%
viz_alexnet.plot_single_setting_aggregated('stat-wmm;128;False;0.003;5;', fontsize=25, filename="model_resnet34", layout='vertical', unixe_idxs=list(idxs))
# Out:
# c:\Users\QbaSo\PycharmProjects\mgr\myCode\Results visualization\visualization.py:405: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(metrics_df.to_latex(index=False))
# \begin{tabular}{rrrrl}
# \toprule
#  task &  acc at the end &  mean acc &  acc loss per task & split \\
# \midrule
#     0 &           81.60 &     84.65 &               2.17 &  test \\
#     1 &           78.35 &     80.50 &               2.09 &  test \\
#     2 &           80.36 &     81.36 &               1.96 &  test \\
#     3 &           86.84 &     86.46 &               2.82 &  test \\
#     4 &           91.84 &     88.81 &               0.00 &  test \\
# \bottomrule
# \end{tabular}

# %%
idxs = viz_alexnet.df[viz_alexnet.df['UID']=='None;128.0;False;0.001;5;'].index.values[:5]

# %%
viz_alexnet.plot_single_setting_aggregated('None;128;False;0.003;5;', fontsize=25, filename="model_resnet34", layout='vertical', unixe_idxs=list(idxs))
# Out:
# c:\Users\QbaSo\PycharmProjects\mgr\myCode\Results visualization\visualization.py:405: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(metrics_df.to_latex(index=False))
# \begin{tabular}{rrrrl}
# \toprule
#  task &  acc at the end &  mean acc &  acc loss per task & split \\
# \midrule
#     0 &           85.02 &     85.09 &               1.29 &  test \\
#     1 &           82.70 &     83.20 &               1.69 &  test \\
#     2 &           90.89 &     89.79 &               1.28 &  test \\
#     3 &           84.30 &     84.35 &               3.25 &  test \\
#     4 &           94.31 &     91.73 &               0.00 &  test \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # VGG

# %%
project = 'rehersal VGG CIFAR10 Task IL'


viz_vgg = Visualization(project=project,UID=['rehearsal_dataset', 'batch_size_rehearsal', 'pretraining', 'learning_rate', 'epochs', 'optimizer'], y_min=30)

# %%
viz_vgg.df.UID.value_counts()
# Out:
# ;128;False;1e-05;5;SGD;      1
# ;128;False;0.1;5;SGD;        1
# ;128;False;0.01;5;SGD;       1
# ;128;False;0.0001;5;Adam;    1
# ;128;False;0.0003;5;Adam;    1
# ;128;False;0.003;5;Adam;     1
# ;128;False;0.01;5;Adam;      1
# ;128;False;3e-05;5;Adam;     1
# ;128;False;0.001;5;Adam;     1
# ;128;False;0.03;5;Adam;      1
# ;128;False;1e-05;5;Adam;     1
# ;128;False;0.003;5;SGD;      1
# ;128;False;0.0001;5;SGD;     1
# ;128;False;0.0003;5;SGD;     1
# ;128;False;0.03;5;SGD;       1
# ;128;False;0.001;5;SGD;      1
# Name: UID, dtype: int64

# %%
viz_vgg.df[viz_vgg.df['UID']=='stat-wmm;128.0;True;0.001;5;'].index.values[:5]
# Out:
# array([], dtype=int64)

# %%
viz_vgg.plot_single_setting_aggregated('stat-wmm;128;False;0.01;5;SGD', fontsize=25, filename="model_resnet34", layout='vertical', unixe_idxs=None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 viz_vgg.plot_single_setting_aggregated('stat-wmm;128;False;0.01;5;SGD', fontsize=25, filename="model_resnet34", layout='vertical', unixe_idxs=None)
#
# File c:\Users\QbaSo\PycharmProjects\mgr\myCode\Results visualization\visualization.py:239, in Visualization.plot_single_setting_aggregated(self, run_param, fontsize, up_postion, filename, layout, plot_till, unixe_idxs)
#     237 def plot_single_setting_aggregated(self, run_param, fontsize=12, up_postion=1.00, filename=None, layout='square', plot_till=None, unixe_idxs=None):
#     238     if not unixe_idxs:
# --> 239         unixe_idxs = self.runs_params_settings_idxs_dict[run_param]
#     240     df_train, df_test = self.extract_data_from_runs(unixe_idxs)
# ...
