# %%
from visualization import Visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
project = 'rehersal ResNet CIFAR10 Task IL'


viz = Visualization(project=project)

# %%
viz.extract_all_runs_metrics()
# Out:
# Could not fetch metrics in run: 200 UID: stat-spectrum_color_wmm;128;True;0.01;5;
# Could not fetch metrics in run: 201 UID: stat-spectrum_color_wmm;128;True;0.01;5;
# Could not fetch metrics in run: 202 UID: stat-spectrum_color_wmm;128;True;0.01;5;
# Could not fetch metrics in run: 203 UID: stat-spectrum_color_wmm;128;True;0.01;5;
# Could not fetch metrics in run: 204 UID: stat-spectrum_color_wmm;128;True;0.01;5;
# Could not fetch metrics in run: 205 UID: stat-spectrum_color_wmm;128;True;0.01;5;

# %%
df = viz.metrics_df.copy()

for i, params in enumerate(df.UID.apply(lambda x: x.split(';'))):
    for c, param in zip(viz.UID, params):
        df.loc[i, c] = param

df = df[(df['learning_rate']=='0.003') & (df['epochs']=='5')]

# %%
df
# Out:
#                                            UID  acc_at_the_end_task_0  \
# 0                  stat-wmm;128;False;0.003;5;              67.750000
# 1                  stat-wmm;128;False;0.003;5;              78.000000
# 2                          ;128;False;0.003;5;              62.900002
# 3                          ;128;False;0.003;5;              74.000000
# 4                          ;128;False;0.003;5;              75.849998
# ..                                         ...                    ...
# 125  stat-spectrum_color_wmm;128;True;0.003;5;              70.099998
# 126  stat-spectrum_color_wmm;128;True;0.003;5;              73.699997
# 127                 stat-wmm;128;True;0.003;5;              67.849998
# 128                 stat-wmm;128;True;0.003;5;              84.050003
# 129                 stat-wmm;128;True;0.003;5;              72.500000
#
#      acc_mean_task_0  acc_mean_decrease_per_task_0   acc_max0   acc_min0  \
# 0           68.61025                      2.799999  78.949997  52.650002
# 1           78.28500                      1.775000  85.099998  48.450001
# 2           69.09425                      4.287500  80.050003  49.099998
# 3           85.00550                      4.287500  91.150002  50.049999
# 4           81.76025                      3.250000  88.849998  50.000000
# ..               ...                           ...        ...        ...
# 125         70.04425                      1.587500  76.449997  55.849998
# 126         76.15200                      2.275002  82.800003  50.200001
# 127         69.08025                      2.275000  76.949997  50.849998
# 128         86.40175                      1.750000  91.050003  53.349998
# 129         72.84050                      1.525000  78.599998  51.599998
#
#      acc_at_the_end_task_1  acc_mean_task_1  acc_mean_decrease_per_task_1  \
# 0                79.250000        78.545000                      1.100001
# 1                86.199997        82.051563                      0.333333
# 2                81.900002        85.199688                      2.216667
# 3                75.949997        87.111875                      5.566668
# 4                69.050003        71.250937                      2.299998
# ..                     ...              ...                           ...
# 125              80.849998        83.436563                      2.350001
# 126              80.650002        82.865313                      2.250000
# 127              68.800003        71.314062                      2.416667
# 128              78.500000        84.659687                      3.850001
# 129              85.150002        84.743750                      0.933332
#
#       acc_max1  ...  acc_mean_task_4  acc_mean_decrease_per_task_4   acc_max4  \
# 0    82.550003  ...        76.998750                  9.500046e-08  80.800003
# 1    87.199997  ...        82.627500                  3.000031e-08  85.550003
# 2    88.550003  ...        89.773749                  4.000015e-08  92.250000
# 3    92.650002  ...        74.648750                  0.000000e+00  80.449997
# 4    75.949997  ...        85.131250                  3.499985e-08  88.650002
# ..         ...  ...              ...                           ...        ...
# 125  87.900002  ...        85.962500                  0.000000e+00  90.250000
# 126  87.400002  ...        71.393751                  1.800003e-07  76.300003
# 127  76.050003  ...        80.378750                  1.199997e-07  84.699997
# 128  90.050003  ...        73.833750                  5.500031e-08  78.650002
# 129  87.949997  ...        77.430000                  0.000000e+00  81.699997
#
#       acc_min4  split        rehearsal_dataset  batch_size_rehearsal  \
# 0    46.549999   test                 stat-wmm                   128
# 1    50.000000   test                 stat-wmm                   128
# 2    46.950001   test                                            128
# 3    47.500000   test                                            128
# 4    48.400002   test                                            128
# ..         ...    ...                      ...                   ...
# 125  42.349998   test  stat-spectrum_color_wmm                   128
# 126  44.400002   test  stat-spectrum_color_wmm                   128
# 127  43.400002   test                 stat-wmm                   128
# 128  46.950001   test                 stat-wmm                   128
# 129  48.000000   test                 stat-wmm                   128
#
#      pretraining  learning_rate  epochs
# 0          False          0.003       5
# 1          False          0.003       5
# 2          False          0.003       5
# 3          False          0.003       5
# 4          False          0.003       5
# ..           ...            ...     ...
# 125         True          0.003       5
# 126         True          0.003       5
# 127         True          0.003       5
# 128         True          0.003       5
# 129         True          0.003       5
#
# [108 rows x 32 columns]

# %%
Visualization.box_plot('acc_at_the_end_task_0', df)

# %%
viz.plot_single_setting(todo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 viz.plot_single_setting(todo)
#
# NameError: name 'todo' is not defined
