# %%
import os
os.chdir("../")

from visualization import Visualization

# %%
project = 'rehersal ResNet34 CIFAR10 Task IL'


viz = Visualization(project=project,UID=['rehearsal_dataset', 'batch_size_rehearsal', 'pretraining', 'learning_rate', 'epochs', 'separate_noise_output','optimizer'])

# %%
viz.extract_all_runs_metrics()

# %%
df = viz.metrics_df.copy()

# %%
df
# Out:
#                                       UID  acc_at_the_end_task_0  \
# 0   stat-wmm;128;False;0.003;5;False;SGD;              73.050003
# 1   stat-wmm;128;False;0.003;5;False;SGD;              55.000000
# 2   stat-wmm;128;False;0.003;5;False;SGD;              58.400002
# 3   stat-wmm;128;False;0.003;5;False;SGD;              76.500000
# 4   stat-wmm;128;False;0.003;5;False;SGD;              80.949997
# ..                                    ...                    ...
# 62         ;128;False;0.0001;5;False;SGD;              64.349998
# 63           ;128;False;0.01;5;False;SGD;              79.550003
# 64           ;128;False;0.03;5;False;SGD;              50.150002
# 65          ;128;False;0.001;5;False;SGD;              76.000000
# 66          ;128;False;3e-05;5;False;SGD;              53.700001
#
#     acc_mean_task_0  acc_mean_decrease_per_task_0   acc_max0   acc_min0  \
# 0         74.936250                      3.824999  88.349998  55.849998
# 1         56.760750                      1.887500  62.549999  50.700001
# 2         65.866000                      5.025000  78.500000  46.700001
# 3         74.484750                      1.637501  83.050003  52.799999
# 4         73.559500                      0.725000  83.849998  49.599998
# ..              ...                           ...        ...        ...
# 62        64.309500                      1.112501  68.800003  45.000000
# 63        82.814573                      2.699999  90.349998  50.000000
# 64        58.865250                      8.525000  84.250000  49.250000
# 65        76.507000                      1.962500  83.849998  49.900002
# 66        55.995500                      1.437500  59.450001  48.849998
#
#     acc_at_the_end_task_1  acc_mean_task_1  acc_mean_decrease_per_task_1  \
# 0               74.500000        74.246250                      1.550001
# 1               68.099998        72.559688                      5.816668
# 2               73.550003        77.873125                      3.599998
# 3               66.750000        67.511563                      1.600001
# 4               68.000000        66.372187                      0.733332
# ..                    ...              ...                           ...
# 62              68.550003        66.449062                      1.216665
# 63              63.299999        77.806563                      9.933333
# 64              63.549999        74.777188                     10.166668
# 65              81.900002        80.323438                      1.333333
# 66              52.450001        52.571250                      0.949999
#
#      acc_max1  ...  pretraining  learning_rate  epochs  separate_noise_output  \
# 0   79.150002  ...        False          0.003       5                  False
# 1   85.550003  ...        False          0.003       5                  False
# 2   84.349998  ...        False          0.003       5                  False
# 3   71.550003  ...        False          0.003       5                  False
# 4   70.199997  ...        False          0.003       5                  False
# ..        ...  ...          ...            ...     ...                    ...
# 62  72.199997  ...        False         0.0001       5                  False
# 63  93.099998  ...        False           0.01       5                  False
# 64  94.050003  ...        False           0.03       5                  False
# 65  85.900002  ...        False          0.001       5                  False
# 66  55.299999  ...        False          3e-05       5                  False
#
#     optimizer  mean_acc_at_the_end  median_acc_at_the_end  mean_acc_mean  \
# 0         SGD            75.570001              73.050003      38.280416
# 1         SGD            69.660000              68.099998      37.093023
# 2         SGD            67.990001              67.599998      38.877746
# 3         SGD            70.750000              70.400002      35.748569
# 4         SGD            76.189999              74.500000      36.733231
# ..        ...                  ...                    ...            ...
# 62        SGD            68.010001              66.300003      33.092835
# 63        SGD            75.960000              77.449997      42.499597
# 64        SGD            66.210001              63.549999      43.513660
# 65        SGD            72.630000              75.449997      37.032169
# 66        SGD            52.760000              52.450001      25.799154
#
#     mean_acc_mean_decrease_per_task  mean_acc_max
# 0                          1.719999     80.729999
# 1                          3.540833     78.230001
# 2                          6.065001     79.640001
# 3                          1.647501     74.940001
# 4                          1.151667     78.720000
# ..                              ...           ...
# 62                         0.870833     70.230000
# 63                         5.521667     88.630000
# 64                        12.568333     90.140001
# 65                         2.349168     77.330000
# 66                         1.157500     55.439999
#
# [67 rows x 39 columns]

# %%
acc_at_the_end_cols = df.columns[df.columns.str.contains('acc_at_the_end_task')]
df['mean_acc_at_the_end'] = df[acc_at_the_end_cols].mean(axis=1)

acc_mean_cols = df.columns[df.columns.str.contains('acc_mean')]
df['mean_acc_mean'] = df[acc_mean_cols].mean(axis=1)

acc_mean_decrease_per_task_cols = df.columns[df.columns.str.contains('acc_mean_decrease_per_task')]
df['mean_acc_mean_decrease_per_task'] = df[acc_mean_decrease_per_task_cols].mean(axis=1)

# %%
df
# Out:
#                                       UID  acc_at_the_end_task_0  \
# 0   stat-wmm;128;False;0.003;5;False;SGD;              73.050003
# 1   stat-wmm;128;False;0.003;5;False;SGD;              55.000000
# 2   stat-wmm;128;False;0.003;5;False;SGD;              58.400002
# 3   stat-wmm;128;False;0.003;5;False;SGD;              76.500000
# 4   stat-wmm;128;False;0.003;5;False;SGD;              80.949997
# ..                                    ...                    ...
# 62         ;128;False;0.0001;5;False;SGD;              64.349998
# 63           ;128;False;0.01;5;False;SGD;              79.550003
# 64           ;128;False;0.03;5;False;SGD;              50.150002
# 65          ;128;False;0.001;5;False;SGD;              76.000000
# 66          ;128;False;3e-05;5;False;SGD;              53.700001
#
#     acc_mean_task_0  acc_mean_decrease_per_task_0   acc_max0   acc_min0  \
# 0         74.936250                      3.824999  88.349998  55.849998
# 1         56.760750                      1.887500  62.549999  50.700001
# 2         65.866000                      5.025000  78.500000  46.700001
# 3         74.484750                      1.637501  83.050003  52.799999
# 4         73.559500                      0.725000  83.849998  49.599998
# ..              ...                           ...        ...        ...
# 62        64.309500                      1.112501  68.800003  45.000000
# 63        82.814573                      2.699999  90.349998  50.000000
# 64        58.865250                      8.525000  84.250000  49.250000
# 65        76.507000                      1.962500  83.849998  49.900002
# 66        55.995500                      1.437500  59.450001  48.849998
#
#     acc_at_the_end_task_1  acc_mean_task_1  acc_mean_decrease_per_task_1  \
# 0               74.500000        74.246250                      1.550001
# 1               68.099998        72.559688                      5.816668
# 2               73.550003        77.873125                      3.599998
# 3               66.750000        67.511563                      1.600001
# 4               68.000000        66.372187                      0.733332
# ..                    ...              ...                           ...
# 62              68.550003        66.449062                      1.216665
# 63              63.299999        77.806563                      9.933333
# 64              63.549999        74.777188                     10.166668
# 65              81.900002        80.323438                      1.333333
# 66              52.450001        52.571250                      0.949999
#
#      acc_max1  ...  pretraining  learning_rate  epochs  separate_noise_output  \
# 0   79.150002  ...        False          0.003       5                  False
# 1   85.550003  ...        False          0.003       5                  False
# 2   84.349998  ...        False          0.003       5                  False
# 3   71.550003  ...        False          0.003       5                  False
# 4   70.199997  ...        False          0.003       5                  False
# ..        ...  ...          ...            ...     ...                    ...
# 62  72.199997  ...        False         0.0001       5                  False
# 63  93.099998  ...        False           0.01       5                  False
# 64  94.050003  ...        False           0.03       5                  False
# 65  85.900002  ...        False          0.001       5                  False
# 66  55.299999  ...        False          3e-05       5                  False
#
#     optimizer  mean_acc_at_the_end  median_acc_at_the_end  mean_acc_mean  \
# 0         SGD            75.570001              73.050003      35.233715
# 1         SGD            69.660000              68.099998      34.297007
# 2         SGD            67.990001              67.599998      36.143351
# 3         SGD            70.750000              70.400002      32.906814
# 4         SGD            76.189999              74.500000      33.768101
# ..        ...                  ...                    ...            ...
# 62        SGD            68.010001              66.300003      30.407668
# 63        SGD            75.960000              77.449997      39.418103
# 64        SGD            66.210001              63.549999      40.934883
# 65        SGD            72.630000              75.449997      34.141919
# 66        SGD            52.760000              52.450001      23.745683
#
#     mean_acc_mean_decrease_per_task  mean_acc_max
# 0                          1.719999     80.729999
# 1                          3.540833     78.230001
# 2                          6.065001     79.640001
# 3                          1.647501     74.940001
# 4                          1.151667     78.720000
# ..                              ...           ...
# 62                         0.870833     70.230000
# 63                         5.521667     88.630000
# 64                        12.568333     90.140001
# 65                         2.349168     77.330000
# 66                         1.157500     55.439999
#
# [67 rows x 39 columns]

# %%
df.UID.value_counts()
# Out:
# ;128;False;0.01;5;False;SGD;             11
# stat-wmm;128;False;0.003;5;False;SGD;    10
# stat-wmm;128;True;0.003;5;False;SGD;     10
# ;128;False;0.003;5;False;SGD;            10
# stat-wmm;128;True;0.01;5;False;SGD;      10
# stat-wmm;128;False;0.01;5;False;SGD;     10
# ;128;False;0.0003;5;False;SGD;            1
# ;128;False;1e-05;5;False;SGD;             1
# ;128;False;0.0001;5;False;SGD;            1
# ;128;False;0.03;5;False;SGD;              1
# ;128;False;0.001;5;False;SGD;             1
# ;128;False;3e-05;5;False;SGD;             1
# Name: UID, dtype: int64

# %%
from matplotlib import pyplot as plt
import numpy as np


def box_plot(metric_name, df, filename=None):
    UIDS = df['UID'].unique()

    values = []
    for uid in UIDS:
        values.append(df[df['UID'] == uid][metric_name].median())

    order = np.argsort(values)
    UIDS = UIDS[order]

    plt.figure(figsize=(20, 10))
    for i, uid in enumerate(UIDS):
        plt.boxplot(df[df['UID'] == uid][metric_name], positions=[i], widths=0.6)

    labels = UIDS
    # labels = [f"{uid.split(';')[3]}" for uid in UIDS]

    plt.xticks(np.arange(len(UIDS)), labels, rotation=90)
    plt.title(f"metic: {metric_name}")
    plt.xlabel("unique identifier")
    plt.ylabel("accuracy [%]")
    plt.show()

    if filename:
        plt.savefig("images/"+filename+".pdf", format='pdf')
        plt.savefig("images/"+filename+".svg", format='svg')

# %%
df
# Out:
#                                       UID  acc_at_the_end_task_0  \
# 0   stat-wmm;128;False;0.003;5;False;SGD;              73.050003
# 1   stat-wmm;128;False;0.003;5;False;SGD;              55.000000
# 2   stat-wmm;128;False;0.003;5;False;SGD;              58.400002
# 3   stat-wmm;128;False;0.003;5;False;SGD;              76.500000
# 4   stat-wmm;128;False;0.003;5;False;SGD;              80.949997
# ..                                    ...                    ...
# 62         ;128;False;0.0001;5;False;SGD;              64.349998
# 63           ;128;False;0.01;5;False;SGD;              79.550003
# 64           ;128;False;0.03;5;False;SGD;              50.150002
# 65          ;128;False;0.001;5;False;SGD;              76.000000
# 66          ;128;False;3e-05;5;False;SGD;              53.700001
#
#     acc_mean_task_0  acc_mean_decrease_per_task_0   acc_max0   acc_min0  \
# 0         74.936250                      3.824999  88.349998  55.849998
# 1         56.760750                      1.887500  62.549999  50.700001
# 2         65.866000                      5.025000  78.500000  46.700001
# 3         74.484750                      1.637501  83.050003  52.799999
# 4         73.559500                      0.725000  83.849998  49.599998
# ..              ...                           ...        ...        ...
# 62        64.309500                      1.112501  68.800003  45.000000
# 63        82.814573                      2.699999  90.349998  50.000000
# 64        58.865250                      8.525000  84.250000  49.250000
# 65        76.507000                      1.962500  83.849998  49.900002
# 66        55.995500                      1.437500  59.450001  48.849998
#
#     acc_at_the_end_task_1  acc_mean_task_1  acc_mean_decrease_per_task_1  \
# 0               74.500000        74.246250                      1.550001
# 1               68.099998        72.559688                      5.816668
# 2               73.550003        77.873125                      3.599998
# 3               66.750000        67.511563                      1.600001
# 4               68.000000        66.372187                      0.733332
# ..                    ...              ...                           ...
# 62              68.550003        66.449062                      1.216665
# 63              63.299999        77.806563                      9.933333
# 64              63.549999        74.777188                     10.166668
# 65              81.900002        80.323438                      1.333333
# 66              52.450001        52.571250                      0.949999
#
#      acc_max1  ...  pretraining  learning_rate  epochs  separate_noise_output  \
# 0   79.150002  ...        False          0.003       5                  False
# 1   85.550003  ...        False          0.003       5                  False
# 2   84.349998  ...        False          0.003       5                  False
# 3   71.550003  ...        False          0.003       5                  False
# 4   70.199997  ...        False          0.003       5                  False
# ..        ...  ...          ...            ...     ...                    ...
# 62  72.199997  ...        False         0.0001       5                  False
# 63  93.099998  ...        False           0.01       5                  False
# 64  94.050003  ...        False           0.03       5                  False
# 65  85.900002  ...        False          0.001       5                  False
# 66  55.299999  ...        False          3e-05       5                  False
#
#     optimizer  mean_acc_at_the_end  median_acc_at_the_end  mean_acc_mean  \
# 0         SGD            75.570001              73.050003      35.233715
# 1         SGD            69.660000              68.099998      34.297007
# 2         SGD            67.990001              67.599998      36.143351
# 3         SGD            70.750000              70.400002      32.906814
# 4         SGD            76.189999              74.500000      33.768101
# ..        ...                  ...                    ...            ...
# 62        SGD            68.010001              66.300003      30.407668
# 63        SGD            75.960000              77.449997      39.418103
# 64        SGD            66.210001              63.549999      40.934883
# 65        SGD            72.630000              75.449997      34.141919
# 66        SGD            52.760000              52.450001      23.745683
#
#     mean_acc_mean_decrease_per_task  mean_acc_max
# 0                          1.719999     80.729999
# 1                          3.540833     78.230001
# 2                          6.065001     79.640001
# 3                          1.647501     74.940001
# 4                          1.151667     78.720000
# ..                              ...           ...
# 62                         0.870833     70.230000
# 63                         5.521667     88.630000
# 64                        12.568333     90.140001
# 65                         2.349168     77.330000
# 66                         1.157500     55.439999
#
# [67 rows x 39 columns]

# %%
box_plot('mean_acc_at_the_end', df)

# %%
viz.plot_everything()
